# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavel184/NLP_basic_course/blob/Homework_lesson_10/Homework_lesson_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### HOMEWORK_LESSON_10

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %% [markdown]
# ## Download and prepare the dataset
#
# We'll use a language dataset provided by http://www.manythings.org/anki/

# %%
# !wget http://www.manythings.org/anki/rus-eng.zip
# Out:
# --2021-12-09 16:02:21--  http://www.manythings.org/anki/rus-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 172.67.186.54, 104.21.92.44, 2606:4700:3030::6815:5c2c, ...
# Connecting to www.manythings.org (www.manythings.org)|172.67.186.54|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14611166 (14M) [application/zip]
# Saving to: ‘rus-eng.zip.1’
#
# rus-eng.zip.1       100%[===================>]  13.93M  61.5MB/s    in 0.2s
#
# 2021-12-09 16:02:21 (61.5 MB/s) - ‘rus-eng.zip.1’ saved [14611166/14611166]

# %%
# !mkdir rus-eng
# !unzip rus-eng.zip -d rus-eng/
# Out:
# mkdir: cannot create directory ‘rus-eng’: File exists
# Archive:  rus-eng.zip
# replace rus-eng/rus.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace rus-eng/_about.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
# !ls /content/rus-eng/ -lah
# Out:
# total 70M
# drwxr-xr-x 2 root root 4.0K Dec  9 15:51 .
# drwxr-xr-x 1 root root 4.0K Dec  9 16:02 ..
# -rw-r--r-- 1 root root 1.5K Nov 29 01:09 _about.txt
# -rw-r--r-- 1 root root  70M Nov 29 01:09 rus.txt

# %%
# Download the file
path_to_file = "/content/rus-eng/rus.txt"

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
preprocess_sentence("I can't go.")
# Out:
# "<start> i can't go . <end>"

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENG, RUS]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)
print(en[0])
print(ru[0])
# Out:
# <start> go . <end>
# <start> марш ! <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### Limit the size of the dataset to experiment faster (optional)

# %%
len(en), len(ru)
# Out:
# (438015, 438015)

# %%
# Try experimenting with the size of that dataset
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 80000 80000 20000 20000

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 5004 ----> посиди
# 14 ----> у
# 79 ----> себя
# 15 ----> в
# 335 ----> комнате
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 111 ----> stay
# 34 ----> in
# 23 ----> your
# 185 ----> room
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# ### Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 300
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 11]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=False,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.lstm = tf.keras.layers.LSTM(self.enc_units,
                                   return_sequences=False,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    

  def call(self, x, hidden):
    x = self.embedding(x)
    output_gru, state_gru = self.gru(x, initial_state = hidden)
    out1, out2, out3 = self.lstm(x, initial_state = [hidden, hidden]) # Добавил LSTM
    result = (state_gru + out3)/2 # Добавил усреднение эмбендингов
    return result

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_hidden = encoder(example_input_batch, sample_hidden)
# print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.lstm = tf.keras.layers.LSTM(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

  def call(self, x, hidden):
    # enc_output shape == (batch_size, max_length, hidden_size)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)

    # passing the concatenated vector to the GRU
    output_gru, state_gru = self.gru(x, initial_state=hidden)

    # passing the concatenated vector to the LSTM
    out1, out2, out3 = self.lstm(x, initial_state=[hidden,hidden]) # Добавил LSTM

    output = (output_gru + out1) / 2 # Добавил усреднение эмбендингов
    state = (state_gru + out3) / 2

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden)

# %%
decoder_sample_x.shape
# Out:
# TensorShape([64, 7316])

# %%
decoder_sample_h.shape
# Out:
# TensorShape([64, 1024])

# %% [markdown]
# ## Define the optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoints (Object-based saving)

# %%
checkpoint_dir = './training_nmt_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden = decoder(dec_input, dec_hidden)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 100

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.6509
# Epoch 1 Batch 100 Loss 2.1322
# Epoch 1 Batch 200 Loss 1.8859
# Epoch 1 Batch 300 Loss 1.7001
# Epoch 1 Batch 400 Loss 1.6130
# Epoch 1 Batch 500 Loss 1.4894
# Epoch 1 Batch 600 Loss 1.4503
# Epoch 1 Batch 700 Loss 1.3330
# Epoch 1 Batch 800 Loss 1.4364
# Epoch 1 Batch 900 Loss 1.2922
# Epoch 1 Batch 1000 Loss 1.3214
# Epoch 1 Batch 1100 Loss 1.1948
# Epoch 1 Batch 1200 Loss 1.2701
# Epoch 1 Loss 1.5716
# Time taken for 1 epoch 99.6855742931366 sec
#
# Epoch 2 Batch 0 Loss 1.1136
# Epoch 2 Batch 100 Loss 1.0658
# Epoch 2 Batch 200 Loss 1.1433
# Epoch 2 Batch 300 Loss 1.1057
# Epoch 2 Batch 400 Loss 0.9894
# Epoch 2 Batch 500 Loss 1.0395
# Epoch 2 Batch 600 Loss 0.9466
# Epoch 2 Batch 700 Loss 0.9665
# Epoch 2 Batch 800 Loss 0.9976
# Epoch 2 Batch 900 Loss 0.9264
# Epoch 2 Batch 1000 Loss 1.0266
# Epoch 2 Batch 1100 Loss 0.9419
# Epoch 2 Batch 1200 Loss 0.8481
# Epoch 2 Loss 1.0129
# Time taken for 1 epoch 73.39178967475891 sec
#
# Epoch 3 Batch 0 Loss 0.7530
# Epoch 3 Batch 100 Loss 0.8119
# Epoch 3 Batch 200 Loss 0.7770
# Epoch 3 Batch 300 Loss 0.7541
# Epoch 3 Batch 400 Loss 0.7282
# Epoch 3 Batch 500 Loss 0.6947
# Epoch 3 Batch 600 Loss 0.7236
# Epoch 3 Batch 700 Loss 0.7203
# Epoch 3 Batch 800 Loss 0.6113
# Epoch 3 Batch 900 Loss 0.6475
# Epoch 3 Batch 1000 Loss 0.7115
# Epoch 3 Batch 1100 Loss 0.7221
# Epoch 3 Batch 1200 Loss 0.6194
# Epoch 3 Loss 0.6930
# Time taken for 1 epoch 72.0872573852539 sec
#
# Epoch 4 Batch 0 Loss 0.4376
# Epoch 4 Batch 100 Loss 0.4268
# Epoch 4 Batch 200 Loss 0.4470
# Epoch 4 Batch 300 Loss 0.4838
# Epoch 4 Batch 400 Loss 0.4925
# Epoch 4 Batch 500 Loss 0.4891
# Epoch 4 Batch 600 Loss 0.5201
# Epoch 4 Batch 700 Loss 0.4741
# Epoch 4 Batch 800 Loss 0.4754
# Epoch 4 Batch 900 Loss 0.3895
# Epoch 4 Batch 1000 Loss 0.3547
# Epoch 4 Batch 1100 Loss 0.4602
# Epoch 4 Batch 1200 Loss 0.3464
# Epoch 4 Loss 0.4409
# Time taken for 1 epoch 73.34703278541565 sec
#
# Epoch 5 Batch 0 Loss 0.2351
# Epoch 5 Batch 100 Loss 0.2829
# Epoch 5 Batch 200 Loss 0.2782
# Epoch 5 Batch 300 Loss 0.3405
# Epoch 5 Batch 400 Loss 0.2770
# Epoch 5 Batch 500 Loss 0.2924
# Epoch 5 Batch 600 Loss 0.3122
# Epoch 5 Batch 700 Loss 0.2517
# Epoch 5 Batch 800 Loss 0.2685
# Epoch 5 Batch 900 Loss 0.2898
# Epoch 5 Batch 1000 Loss 0.2962
# Epoch 5 Batch 1100 Loss 0.3099
# Epoch 5 Batch 1200 Loss 0.2883
# Epoch 5 Loss 0.2774
# Time taken for 1 epoch 72.03854465484619 sec
#
# Epoch 6 Batch 0 Loss 0.1644
# Epoch 6 Batch 100 Loss 0.1427
# Epoch 6 Batch 200 Loss 0.1587
# Epoch 6 Batch 300 Loss 0.1260
# Epoch 6 Batch 400 Loss 0.1783
# Epoch 6 Batch 500 Loss 0.1382
# Epoch 6 Batch 600 Loss 0.2264
# Epoch 6 Batch 700 Loss 0.1461
# Epoch 6 Batch 800 Loss 0.1780
# Epoch 6 Batch 900 Loss 0.2171
# Epoch 6 Batch 1000 Loss 0.1819
# Epoch 6 Batch 1100 Loss 0.2161
# Epoch 6 Batch 1200 Loss 0.2285
# Epoch 6 Loss 0.1858
# Time taken for 1 epoch 73.20988416671753 sec
#
# Epoch 7 Batch 0 Loss 0.1097
# Epoch 7 Batch 100 Loss 0.1057
# Epoch 7 Batch 200 Loss 0.1089
# Epoch 7 Batch 300 Loss 0.1267
# Epoch 7 Batch 400 Loss 0.1377
# Epoch 7 Batch 500 Loss 0.1414
# Epoch 7 Batch 600 Loss 0.1261
# Epoch 7 Batch 700 Loss 0.1325
# Epoch 7 Batch 800 Loss 0.1610
# Epoch 7 Batch 900 Loss 0.1337
# Epoch 7 Batch 1000 Loss 0.1310
# Epoch 7 Batch 1100 Loss 0.1019
# Epoch 7 Batch 1200 Loss 0.1792
# Epoch 7 Loss 0.1376
# Time taken for 1 epoch 72.22010493278503 sec
#
# Epoch 8 Batch 0 Loss 0.0815
# Epoch 8 Batch 100 Loss 0.1111
# Epoch 8 Batch 200 Loss 0.1384
# Epoch 8 Batch 300 Loss 0.1287
# Epoch 8 Batch 400 Loss 0.1030
# Epoch 8 Batch 500 Loss 0.0961
# Epoch 8 Batch 600 Loss 0.1088
# Epoch 8 Batch 700 Loss 0.0916
# Epoch 8 Batch 800 Loss 0.1486
# Epoch 8 Batch 900 Loss 0.1314
# Epoch 8 Batch 1000 Loss 0.1457
# Epoch 8 Batch 1100 Loss 0.1321
# Epoch 8 Batch 1200 Loss 0.1113
# Epoch 8 Loss 0.1126
# Time taken for 1 epoch 73.23522400856018 sec
#
# Epoch 9 Batch 0 Loss 0.0898
# Epoch 9 Batch 100 Loss 0.0727
# Epoch 9 Batch 200 Loss 0.0680
# Epoch 9 Batch 300 Loss 0.0624
# Epoch 9 Batch 400 Loss 0.0659
# Epoch 9 Batch 500 Loss 0.0857
# Epoch 9 Batch 600 Loss 0.1264
# Epoch 9 Batch 700 Loss 0.0911
# Epoch 9 Batch 800 Loss 0.1032
# Epoch 9 Batch 900 Loss 0.0738
# Epoch 9 Batch 1000 Loss 0.1122
# Epoch 9 Batch 1100 Loss 0.1078
# Epoch 9 Batch 1200 Loss 0.1715
# Epoch 9 Loss 0.0983
# Time taken for 1 epoch 72.15368795394897 sec
#
# Epoch 10 Batch 0 Loss 0.0571
# Epoch 10 Batch 100 Loss 0.1032
# Epoch 10 Batch 200 Loss 0.0601
# Epoch 10 Batch 300 Loss 0.0840
# Epoch 10 Batch 400 Loss 0.0574
# Epoch 10 Batch 500 Loss 0.0944
# Epoch 10 Batch 600 Loss 0.0790
# Epoch 10 Batch 700 Loss 0.0838
# Epoch 10 Batch 800 Loss 0.0731
# Epoch 10 Batch 900 Loss 0.0956
# Epoch 10 Batch 1000 Loss 0.0724
# Epoch 10 Batch 1100 Loss 0.1220
# Epoch 10 Batch 1200 Loss 0.1336
# Epoch 10 Loss 0.0893
# Time taken for 1 epoch 73.2873272895813 sec
#
# Epoch 11 Batch 0 Loss 0.0870
# Epoch 11 Batch 100 Loss 0.0819
# Epoch 11 Batch 200 Loss 0.0573
# Epoch 11 Batch 300 Loss 0.0733
# Epoch 11 Batch 400 Loss 0.0655
# Epoch 11 Batch 500 Loss 0.0803
# Epoch 11 Batch 600 Loss 0.0604
# Epoch 11 Batch 700 Loss 0.0863
# Epoch 11 Batch 800 Loss 0.0753
# Epoch 11 Batch 900 Loss 0.1106
# Epoch 11 Batch 1000 Loss 0.1298
# Epoch 11 Batch 1100 Loss 0.1325
# Epoch 11 Batch 1200 Loss 0.1015
# Epoch 11 Loss 0.0835
# Time taken for 1 epoch 72.1565318107605 sec
#
# Epoch 12 Batch 0 Loss 0.0764
# Epoch 12 Batch 100 Loss 0.0533
# Epoch 12 Batch 200 Loss 0.0460
# Epoch 12 Batch 300 Loss 0.0513
# Epoch 12 Batch 400 Loss 0.0874
# Epoch 12 Batch 500 Loss 0.1018
# Epoch 12 Batch 600 Loss 0.1023
# Epoch 12 Batch 700 Loss 0.0735
# Epoch 12 Batch 800 Loss 0.0444
# Epoch 12 Batch 900 Loss 0.0835
# Epoch 12 Batch 1000 Loss 0.1216
# Epoch 12 Batch 1100 Loss 0.0890
# Epoch 12 Batch 1200 Loss 0.0864
# Epoch 12 Loss 0.0791
# Time taken for 1 epoch 73.32683444023132 sec
#
# Epoch 13 Batch 0 Loss 0.0719
# Epoch 13 Batch 100 Loss 0.0727
# Epoch 13 Batch 200 Loss 0.0559
# Epoch 13 Batch 300 Loss 0.0876
# Epoch 13 Batch 400 Loss 0.0558
# Epoch 13 Batch 500 Loss 0.0500
# Epoch 13 Batch 600 Loss 0.1285
# Epoch 13 Batch 700 Loss 0.0831
# Epoch 13 Batch 800 Loss 0.0691
# Epoch 13 Batch 900 Loss 0.0828
# Epoch 13 Batch 1000 Loss 0.0480
# Epoch 13 Batch 1100 Loss 0.1027
# Epoch 13 Batch 1200 Loss 0.0787
# Epoch 13 Loss 0.0756
# Time taken for 1 epoch 72.1876859664917 sec
#
# Epoch 14 Batch 0 Loss 0.0854
# Epoch 14 Batch 100 Loss 0.0450
# Epoch 14 Batch 200 Loss 0.0959
# Epoch 14 Batch 300 Loss 0.0546
# Epoch 14 Batch 400 Loss 0.0623
# Epoch 14 Batch 500 Loss 0.0422
# Epoch 14 Batch 600 Loss 0.0563
# Epoch 14 Batch 700 Loss 0.0749
# Epoch 14 Batch 800 Loss 0.0914
# Epoch 14 Batch 900 Loss 0.0647
# Epoch 14 Batch 1000 Loss 0.0802
# Epoch 14 Batch 1100 Loss 0.0810
# Epoch 14 Batch 1200 Loss 0.0631
# Epoch 14 Loss 0.0732
# Time taken for 1 epoch 73.32904648780823 sec
#
# Epoch 15 Batch 0 Loss 0.0528
# Epoch 15 Batch 100 Loss 0.0815
# Epoch 15 Batch 200 Loss 0.0432
# Epoch 15 Batch 300 Loss 0.0985
# Epoch 15 Batch 400 Loss 0.0821
# Epoch 15 Batch 500 Loss 0.0519
# Epoch 15 Batch 600 Loss 0.0732
# Epoch 15 Batch 700 Loss 0.0920
# Epoch 15 Batch 800 Loss 0.0662
# Epoch 15 Batch 900 Loss 0.0737
# Epoch 15 Batch 1000 Loss 0.1011
# Epoch 15 Batch 1100 Loss 0.0853
# Epoch 15 Batch 1200 Loss 0.0748
# Epoch 15 Loss 0.0705
# Time taken for 1 epoch 72.07382678985596 sec
#
# Epoch 16 Batch 0 Loss 0.0504
# Epoch 16 Batch 100 Loss 0.0934
# Epoch 16 Batch 200 Loss 0.0231
# Epoch 16 Batch 300 Loss 0.0643
# Epoch 16 Batch 400 Loss 0.0644
# Epoch 16 Batch 500 Loss 0.0435
# Epoch 16 Batch 600 Loss 0.0834
# Epoch 16 Batch 700 Loss 0.0436
# Epoch 16 Batch 800 Loss 0.0727
# Epoch 16 Batch 900 Loss 0.0951
# Epoch 16 Batch 1000 Loss 0.0701
# Epoch 16 Batch 1100 Loss 0.1163
# Epoch 16 Batch 1200 Loss 0.0582
# Epoch 16 Loss 0.0685
# Time taken for 1 epoch 73.14202904701233 sec
#
# Epoch 17 Batch 0 Loss 0.0720
# Epoch 17 Batch 100 Loss 0.0580
# Epoch 17 Batch 200 Loss 0.0597
# Epoch 17 Batch 300 Loss 0.0729
# Epoch 17 Batch 400 Loss 0.0507
# Epoch 17 Batch 500 Loss 0.0560
# Epoch 17 Batch 600 Loss 0.0482
# Epoch 17 Batch 700 Loss 0.0550
# Epoch 17 Batch 800 Loss 0.0412
# Epoch 17 Batch 900 Loss 0.0512
# Epoch 17 Batch 1000 Loss 0.0956
# Epoch 17 Batch 1100 Loss 0.0963
# Epoch 17 Batch 1200 Loss 0.0939
# Epoch 17 Loss 0.0668
# Time taken for 1 epoch 72.14010334014893 sec
#
# Epoch 18 Batch 0 Loss 0.0462
# Epoch 18 Batch 100 Loss 0.0836
# Epoch 18 Batch 200 Loss 0.0278
# Epoch 18 Batch 300 Loss 0.0274
# Epoch 18 Batch 400 Loss 0.0377
# Epoch 18 Batch 500 Loss 0.0558
# Epoch 18 Batch 600 Loss 0.0581
# Epoch 18 Batch 700 Loss 0.0706
# Epoch 18 Batch 800 Loss 0.0477
# Epoch 18 Batch 900 Loss 0.0567
# Epoch 18 Batch 1000 Loss 0.0478
# Epoch 18 Batch 1100 Loss 0.0542
# Epoch 18 Batch 1200 Loss 0.0586
# Epoch 18 Loss 0.0645
# Time taken for 1 epoch 73.12186622619629 sec
#
# Epoch 19 Batch 0 Loss 0.0362
# Epoch 19 Batch 100 Loss 0.0662
# Epoch 19 Batch 200 Loss 0.0451
# Epoch 19 Batch 300 Loss 0.0514
# Epoch 19 Batch 400 Loss 0.0551
# Epoch 19 Batch 500 Loss 0.0321
# Epoch 19 Batch 600 Loss 0.0535
# Epoch 19 Batch 700 Loss 0.0729
# Epoch 19 Batch 800 Loss 0.1014
# Epoch 19 Batch 900 Loss 0.0817
# Epoch 19 Batch 1000 Loss 0.0623
# Epoch 19 Batch 1100 Loss 0.0664
# Epoch 19 Batch 1200 Loss 0.0808
# Epoch 19 Loss 0.0633
# Time taken for 1 epoch 72.11000990867615 sec
#
# Epoch 20 Batch 0 Loss 0.0752
# Epoch 20 Batch 100 Loss 0.0411
# Epoch 20 Batch 200 Loss 0.0665
# Epoch 20 Batch 300 Loss 0.0480
# Epoch 20 Batch 400 Loss 0.0716
# Epoch 20 Batch 500 Loss 0.0326
# Epoch 20 Batch 600 Loss 0.0592
# Epoch 20 Batch 700 Loss 0.0672
# Epoch 20 Batch 800 Loss 0.0825
# Epoch 20 Batch 900 Loss 0.0827
# Epoch 20 Batch 1000 Loss 0.0606
# Epoch 20 Batch 1100 Loss 0.0680
# Epoch 20 Batch 1200 Loss 0.0639
# Epoch 20 Loss 0.0620
# Time taken for 1 epoch 73.15891122817993 sec
#
# Epoch 21 Batch 0 Loss 0.0406
# Epoch 21 Batch 100 Loss 0.0408
# Epoch 21 Batch 200 Loss 0.0554
# Epoch 21 Batch 300 Loss 0.0683
# Epoch 21 Batch 400 Loss 0.0393
# Epoch 21 Batch 500 Loss 0.0412
# Epoch 21 Batch 600 Loss 0.0512
# Epoch 21 Batch 700 Loss 0.0905
# Epoch 21 Batch 800 Loss 0.0335
# Epoch 21 Batch 900 Loss 0.0473
# Epoch 21 Batch 1000 Loss 0.1099
# Epoch 21 Batch 1100 Loss 0.0709
# Epoch 21 Batch 1200 Loss 0.0850
# Epoch 21 Loss 0.0604
# Time taken for 1 epoch 72.10197830200195 sec
#
# Epoch 22 Batch 0 Loss 0.0236
# Epoch 22 Batch 100 Loss 0.0241
# Epoch 22 Batch 200 Loss 0.0499
# Epoch 22 Batch 300 Loss 0.0618
# Epoch 22 Batch 400 Loss 0.0904
# Epoch 22 Batch 500 Loss 0.1045
# Epoch 22 Batch 600 Loss 0.0421
# Epoch 22 Batch 700 Loss 0.0405
# Epoch 22 Batch 800 Loss 0.1016
# Epoch 22 Batch 900 Loss 0.0681
# Epoch 22 Batch 1000 Loss 0.0399
# Epoch 22 Batch 1100 Loss 0.0510
# Epoch 22 Batch 1200 Loss 0.0322
# Epoch 22 Loss 0.0592
# Time taken for 1 epoch 73.25833344459534 sec
#
# Epoch 23 Batch 0 Loss 0.0573
# Epoch 23 Batch 100 Loss 0.0771
# Epoch 23 Batch 200 Loss 0.0587
# Epoch 23 Batch 300 Loss 0.0781
# Epoch 23 Batch 400 Loss 0.0841
# Epoch 23 Batch 500 Loss 0.0347
# Epoch 23 Batch 600 Loss 0.0565
# Epoch 23 Batch 700 Loss 0.0511
# Epoch 23 Batch 800 Loss 0.0671
# Epoch 23 Batch 900 Loss 0.0534
# Epoch 23 Batch 1000 Loss 0.0836
# Epoch 23 Batch 1100 Loss 0.0951
# Epoch 23 Batch 1200 Loss 0.0388
# Epoch 23 Loss 0.0581
# Time taken for 1 epoch 71.89909768104553 sec
#
# Epoch 24 Batch 0 Loss 0.0639
# Epoch 24 Batch 100 Loss 0.0452
# Epoch 24 Batch 200 Loss 0.0724
# Epoch 24 Batch 300 Loss 0.0292
# Epoch 24 Batch 400 Loss 0.0681
# Epoch 24 Batch 500 Loss 0.0762
# Epoch 24 Batch 600 Loss 0.0492
# Epoch 24 Batch 700 Loss 0.0498
# Epoch 24 Batch 800 Loss 0.0328
# Epoch 24 Batch 900 Loss 0.0174
# Epoch 24 Batch 1000 Loss 0.0483
# Epoch 24 Batch 1100 Loss 0.0604
# Epoch 24 Batch 1200 Loss 0.0693
# Epoch 24 Loss 0.0566
# Time taken for 1 epoch 73.30570483207703 sec
#
# Epoch 25 Batch 0 Loss 0.0333
# Epoch 25 Batch 100 Loss 0.0540
# Epoch 25 Batch 200 Loss 0.0586
# Epoch 25 Batch 300 Loss 0.0484
# Epoch 25 Batch 400 Loss 0.0371
# Epoch 25 Batch 500 Loss 0.0270
# Epoch 25 Batch 600 Loss 0.0643
# Epoch 25 Batch 700 Loss 0.0523
# Epoch 25 Batch 800 Loss 0.0576
# Epoch 25 Batch 900 Loss 0.0961
# Epoch 25 Batch 1000 Loss 0.0365
# Epoch 25 Batch 1100 Loss 0.0691
# Epoch 25 Batch 1200 Loss 0.0552
# Epoch 25 Loss 0.0556
# Time taken for 1 epoch 72.10646104812622 sec
#
# Epoch 26 Batch 0 Loss 0.0635
# Epoch 26 Batch 100 Loss 0.0355
# Epoch 26 Batch 200 Loss 0.0309
# Epoch 26 Batch 300 Loss 0.0557
# Epoch 26 Batch 400 Loss 0.0400
# Epoch 26 Batch 500 Loss 0.0524
# Epoch 26 Batch 600 Loss 0.0483
# Epoch 26 Batch 700 Loss 0.0477
# Epoch 26 Batch 800 Loss 0.0500
# Epoch 26 Batch 900 Loss 0.0413
# Epoch 26 Batch 1000 Loss 0.0705
# Epoch 26 Batch 1100 Loss 0.0743
# Epoch 26 Batch 1200 Loss 0.0525
# Epoch 26 Loss 0.0550
# Time taken for 1 epoch 73.33700275421143 sec
#
# Epoch 27 Batch 0 Loss 0.0760
# Epoch 27 Batch 100 Loss 0.0505
# Epoch 27 Batch 200 Loss 0.0322
# Epoch 27 Batch 300 Loss 0.0594
# Epoch 27 Batch 400 Loss 0.0441
# Epoch 27 Batch 500 Loss 0.0475
# Epoch 27 Batch 600 Loss 0.0553
# Epoch 27 Batch 700 Loss 0.0686
# Epoch 27 Batch 800 Loss 0.0674
# Epoch 27 Batch 900 Loss 0.0476
# Epoch 27 Batch 1000 Loss 0.0531
# Epoch 27 Batch 1100 Loss 0.0388
# Epoch 27 Batch 1200 Loss 0.0349
# Epoch 27 Loss 0.0537
# Time taken for 1 epoch 72.0750904083252 sec
#
# Epoch 28 Batch 0 Loss 0.0682
# Epoch 28 Batch 100 Loss 0.0332
# Epoch 28 Batch 200 Loss 0.0558
# Epoch 28 Batch 300 Loss 0.0296
# Epoch 28 Batch 400 Loss 0.0473
# Epoch 28 Batch 500 Loss 0.0526
# Epoch 28 Batch 600 Loss 0.0546
# Epoch 28 Batch 700 Loss 0.0411
# Epoch 28 Batch 800 Loss 0.0515
# Epoch 28 Batch 900 Loss 0.0623
# Epoch 28 Batch 1000 Loss 0.0509
# Epoch 28 Batch 1100 Loss 0.0572
# Epoch 28 Batch 1200 Loss 0.0565
# Epoch 28 Loss 0.0534
# Time taken for 1 epoch 73.22156071662903 sec
#
# Epoch 29 Batch 0 Loss 0.0608
# Epoch 29 Batch 100 Loss 0.0534
# Epoch 29 Batch 200 Loss 0.0432
# Epoch 29 Batch 300 Loss 0.0561
# Epoch 29 Batch 400 Loss 0.0510
# Epoch 29 Batch 500 Loss 0.0471
# Epoch 29 Batch 600 Loss 0.0323
# Epoch 29 Batch 700 Loss 0.0361
# Epoch 29 Batch 800 Loss 0.0282
# Epoch 29 Batch 900 Loss 0.0793
# Epoch 29 Batch 1000 Loss 0.0689
# Epoch 29 Batch 1100 Loss 0.0568
# Epoch 29 Batch 1200 Loss 0.0726
# Epoch 29 Loss 0.0519
# Time taken for 1 epoch 72.05072379112244 sec
#
# Epoch 30 Batch 0 Loss 0.0258
# Epoch 30 Batch 100 Loss 0.0208
# Epoch 30 Batch 200 Loss 0.0560
# Epoch 30 Batch 300 Loss 0.0406
# Epoch 30 Batch 400 Loss 0.0506
# Epoch 30 Batch 500 Loss 0.0485
# Epoch 30 Batch 600 Loss 0.0447
# Epoch 30 Batch 700 Loss 0.0535
# Epoch 30 Batch 800 Loss 0.0831
# Epoch 30 Batch 900 Loss 0.0547
# Epoch 30 Batch 1000 Loss 0.0392
# Epoch 30 Batch 1100 Loss 0.0642
# Epoch 30 Batch 1200 Loss 0.0524
# Epoch 30 Loss 0.0507
# Time taken for 1 epoch 73.15688347816467 sec
#
# Epoch 31 Batch 0 Loss 0.0445
# Epoch 31 Batch 100 Loss 0.0254
# Epoch 31 Batch 200 Loss 0.0344
# Epoch 31 Batch 300 Loss 0.0468
# Epoch 31 Batch 400 Loss 0.0401
# Epoch 31 Batch 500 Loss 0.0276
# Epoch 31 Batch 600 Loss 0.0570
# Epoch 31 Batch 700 Loss 0.0625
# Epoch 31 Batch 800 Loss 0.0567
# Epoch 31 Batch 900 Loss 0.0307
# Epoch 31 Batch 1000 Loss 0.0387
# Epoch 31 Batch 1100 Loss 0.0291
# Epoch 31 Batch 1200 Loss 0.0441
# Epoch 31 Loss 0.0503
# Time taken for 1 epoch 72.12048840522766 sec
#
# Epoch 32 Batch 0 Loss 0.0444
# Epoch 32 Batch 100 Loss 0.0457
# Epoch 32 Batch 200 Loss 0.0514
# Epoch 32 Batch 300 Loss 0.0270
# Epoch 32 Batch 400 Loss 0.0371
# Epoch 32 Batch 500 Loss 0.0334
# Epoch 32 Batch 600 Loss 0.0589
# Epoch 32 Batch 700 Loss 0.0386
# Epoch 32 Batch 800 Loss 0.0869
# Epoch 32 Batch 900 Loss 0.0506
# Epoch 32 Batch 1000 Loss 0.0558
# Epoch 32 Batch 1100 Loss 0.0436
# Epoch 32 Batch 1200 Loss 0.0714
# Epoch 32 Loss 0.0494
# Time taken for 1 epoch 73.22805547714233 sec
#
# Epoch 33 Batch 0 Loss 0.0651
# Epoch 33 Batch 100 Loss 0.0467
# Epoch 33 Batch 200 Loss 0.0265
# Epoch 33 Batch 300 Loss 0.0322
# Epoch 33 Batch 400 Loss 0.0280
# Epoch 33 Batch 500 Loss 0.0692
# Epoch 33 Batch 600 Loss 0.0297
# Epoch 33 Batch 700 Loss 0.0406
# Epoch 33 Batch 800 Loss 0.0498
# Epoch 33 Batch 900 Loss 0.0427
# Epoch 33 Batch 1000 Loss 0.0341
# Epoch 33 Batch 1100 Loss 0.0448
# Epoch 33 Batch 1200 Loss 0.0370
# Epoch 33 Loss 0.0477
# Time taken for 1 epoch 72.02135348320007 sec
#
# Epoch 34 Batch 0 Loss 0.0400
# Epoch 34 Batch 100 Loss 0.0320
# Epoch 34 Batch 200 Loss 0.0620
# Epoch 34 Batch 300 Loss 0.0553
# Epoch 34 Batch 400 Loss 0.0454
# Epoch 34 Batch 500 Loss 0.0200
# Epoch 34 Batch 600 Loss 0.0412
# Epoch 34 Batch 700 Loss 0.0431
# Epoch 34 Batch 800 Loss 0.0761
# Epoch 34 Batch 900 Loss 0.0346
# Epoch 34 Batch 1000 Loss 0.0481
# Epoch 34 Batch 1100 Loss 0.0490
# Epoch 34 Batch 1200 Loss 0.0532
# Epoch 34 Loss 0.0480
# Time taken for 1 epoch 73.19267129898071 sec
#
# Epoch 35 Batch 0 Loss 0.0261
# Epoch 35 Batch 100 Loss 0.0416
# Epoch 35 Batch 200 Loss 0.0645
# Epoch 35 Batch 300 Loss 0.0334
# Epoch 35 Batch 400 Loss 0.0452
# Epoch 35 Batch 500 Loss 0.0147
# Epoch 35 Batch 600 Loss 0.0460
# Epoch 35 Batch 700 Loss 0.0566
# Epoch 35 Batch 800 Loss 0.0615
# Epoch 35 Batch 900 Loss 0.0303
# Epoch 35 Batch 1000 Loss 0.0451
# Epoch 35 Batch 1100 Loss 0.0662
# Epoch 35 Batch 1200 Loss 0.0639
# Epoch 35 Loss 0.0475
# Time taken for 1 epoch 72.10714745521545 sec
#
# Epoch 36 Batch 0 Loss 0.0338
# Epoch 36 Batch 100 Loss 0.0355
# Epoch 36 Batch 200 Loss 0.0625
# Epoch 36 Batch 300 Loss 0.0244
# Epoch 36 Batch 400 Loss 0.0409
# Epoch 36 Batch 500 Loss 0.0358
# Epoch 36 Batch 600 Loss 0.0360
# Epoch 36 Batch 700 Loss 0.0341
# Epoch 36 Batch 800 Loss 0.0836
# Epoch 36 Batch 900 Loss 0.0553
# Epoch 36 Batch 1000 Loss 0.0646
# Epoch 36 Batch 1100 Loss 0.0491
# Epoch 36 Batch 1200 Loss 0.0336
# Epoch 36 Loss 0.0464
# Time taken for 1 epoch 73.51422047615051 sec
#
# Epoch 37 Batch 0 Loss 0.0352
# Epoch 37 Batch 100 Loss 0.0159
# Epoch 37 Batch 200 Loss 0.0344
# Epoch 37 Batch 300 Loss 0.0236
# Epoch 37 Batch 400 Loss 0.0389
# Epoch 37 Batch 500 Loss 0.0303
# Epoch 37 Batch 600 Loss 0.0499
# Epoch 37 Batch 700 Loss 0.0420
# Epoch 37 Batch 800 Loss 0.0558
# Epoch 37 Batch 900 Loss 0.0495
# Epoch 37 Batch 1000 Loss 0.0162
# Epoch 37 Batch 1100 Loss 0.0602
# Epoch 37 Batch 1200 Loss 0.0336
# Epoch 37 Loss 0.0460
# Time taken for 1 epoch 72.06643009185791 sec
#
# Epoch 38 Batch 0 Loss 0.0404
# Epoch 38 Batch 100 Loss 0.0328
# Epoch 38 Batch 200 Loss 0.0706
# Epoch 38 Batch 300 Loss 0.0540
# Epoch 38 Batch 400 Loss 0.0877
# Epoch 38 Batch 500 Loss 0.0451
# Epoch 38 Batch 600 Loss 0.0360
# Epoch 38 Batch 700 Loss 0.0177
# Epoch 38 Batch 800 Loss 0.0603
# Epoch 38 Batch 900 Loss 0.0365
# Epoch 38 Batch 1000 Loss 0.0557
# Epoch 38 Batch 1100 Loss 0.0342
# Epoch 38 Batch 1200 Loss 0.0439
# Epoch 38 Loss 0.0450
# Time taken for 1 epoch 73.195481300354 sec
#
# Epoch 39 Batch 0 Loss 0.0239
# Epoch 39 Batch 100 Loss 0.0450
# Epoch 39 Batch 200 Loss 0.0495
# Epoch 39 Batch 300 Loss 0.0257
# Epoch 39 Batch 400 Loss 0.0465
# Epoch 39 Batch 500 Loss 0.0250
# Epoch 39 Batch 600 Loss 0.0464
# Epoch 39 Batch 700 Loss 0.0151
# Epoch 39 Batch 800 Loss 0.0508
# Epoch 39 Batch 900 Loss 0.0540
# Epoch 39 Batch 1000 Loss 0.0413
# Epoch 39 Batch 1100 Loss 0.0299
# Epoch 39 Batch 1200 Loss 0.0578
# Epoch 39 Loss 0.0447
# Time taken for 1 epoch 72.22130084037781 sec
#
# Epoch 40 Batch 0 Loss 0.0623
# Epoch 40 Batch 100 Loss 0.0314
# Epoch 40 Batch 200 Loss 0.0496
# Epoch 40 Batch 300 Loss 0.0332
# Epoch 40 Batch 400 Loss 0.0533
# Epoch 40 Batch 500 Loss 0.0428
# Epoch 40 Batch 600 Loss 0.0424
# Epoch 40 Batch 700 Loss 0.0315
# Epoch 40 Batch 800 Loss 0.0603
# Epoch 40 Batch 900 Loss 0.0565
# Epoch 40 Batch 1000 Loss 0.0404
# Epoch 40 Batch 1100 Loss 0.0955
# Epoch 40 Batch 1200 Loss 0.0360
# Epoch 40 Loss 0.0442
# Time taken for 1 epoch 73.34142088890076 sec
#
# Epoch 41 Batch 0 Loss 0.0234
# Epoch 41 Batch 100 Loss 0.0433
# Epoch 41 Batch 200 Loss 0.0179
# Epoch 41 Batch 300 Loss 0.0410
# Epoch 41 Batch 400 Loss 0.0371
# Epoch 41 Batch 500 Loss 0.0482
# Epoch 41 Batch 600 Loss 0.0356
# Epoch 41 Batch 700 Loss 0.0489
# Epoch 41 Batch 800 Loss 0.0550
# Epoch 41 Batch 900 Loss 0.0536
# Epoch 41 Batch 1000 Loss 0.0447
# Epoch 41 Batch 1100 Loss 0.0373
# Epoch 41 Batch 1200 Loss 0.0517
# Epoch 41 Loss 0.0437
# Time taken for 1 epoch 72.16018486022949 sec
#
# Epoch 42 Batch 0 Loss 0.0348
# Epoch 42 Batch 100 Loss 0.0122
# Epoch 42 Batch 200 Loss 0.0554
# Epoch 42 Batch 300 Loss 0.0233
# Epoch 42 Batch 400 Loss 0.0384
# Epoch 42 Batch 500 Loss 0.0558
# Epoch 42 Batch 600 Loss 0.0281
# Epoch 42 Batch 700 Loss 0.0379
# Epoch 42 Batch 800 Loss 0.0448
# Epoch 42 Batch 900 Loss 0.0505
# Epoch 42 Batch 1000 Loss 0.0339
# Epoch 42 Batch 1100 Loss 0.0393
# Epoch 42 Batch 1200 Loss 0.0762
# Epoch 42 Loss 0.0426
# Time taken for 1 epoch 73.42529320716858 sec
#
# Epoch 43 Batch 0 Loss 0.0303
# Epoch 43 Batch 100 Loss 0.0441
# Epoch 43 Batch 200 Loss 0.0451
# Epoch 43 Batch 300 Loss 0.0422
# Epoch 43 Batch 400 Loss 0.0437
# Epoch 43 Batch 500 Loss 0.0496
# Epoch 43 Batch 600 Loss 0.0410
# Epoch 43 Batch 700 Loss 0.0488
# Epoch 43 Batch 800 Loss 0.0487
# Epoch 43 Batch 900 Loss 0.0417
# Epoch 43 Batch 1000 Loss 0.0512
# Epoch 43 Batch 1100 Loss 0.0662
# Epoch 43 Batch 1200 Loss 0.0579
# Epoch 43 Loss 0.0419
# Time taken for 1 epoch 72.16165971755981 sec
#
# Epoch 44 Batch 0 Loss 0.0502
# Epoch 44 Batch 100 Loss 0.0494
# Epoch 44 Batch 200 Loss 0.0334
# Epoch 44 Batch 300 Loss 0.0340
# Epoch 44 Batch 400 Loss 0.0396
# Epoch 44 Batch 500 Loss 0.0346
# Epoch 44 Batch 600 Loss 0.0392
# Epoch 44 Batch 700 Loss 0.0518
# Epoch 44 Batch 800 Loss 0.0598
# Epoch 44 Batch 900 Loss 0.0452
# Epoch 44 Batch 1000 Loss 0.0208
# Epoch 44 Batch 1100 Loss 0.0480
# Epoch 44 Batch 1200 Loss 0.0400
# Epoch 44 Loss 0.0419
# Time taken for 1 epoch 73.33120322227478 sec
#
# Epoch 45 Batch 0 Loss 0.0225
# Epoch 45 Batch 100 Loss 0.0298
# Epoch 45 Batch 200 Loss 0.0351
# Epoch 45 Batch 300 Loss 0.0418
# Epoch 45 Batch 400 Loss 0.0399
# Epoch 45 Batch 500 Loss 0.0480
# Epoch 45 Batch 600 Loss 0.0408
# Epoch 45 Batch 700 Loss 0.0573
# Epoch 45 Batch 800 Loss 0.0641
# Epoch 45 Batch 900 Loss 0.0396
# Epoch 45 Batch 1000 Loss 0.0383
# Epoch 45 Batch 1100 Loss 0.0438
# Epoch 45 Batch 1200 Loss 0.0320
# Epoch 45 Loss 0.0411
# Time taken for 1 epoch 71.97222447395325 sec
#
# Epoch 46 Batch 0 Loss 0.0315
# Epoch 46 Batch 100 Loss 0.0310
# Epoch 46 Batch 200 Loss 0.0301
# Epoch 46 Batch 300 Loss 0.0332
# Epoch 46 Batch 400 Loss 0.0466
# Epoch 46 Batch 500 Loss 0.0205
# Epoch 46 Batch 600 Loss 0.0714
# Epoch 46 Batch 700 Loss 0.0383
# Epoch 46 Batch 800 Loss 0.0198
# Epoch 46 Batch 900 Loss 0.0400
# Epoch 46 Batch 1000 Loss 0.0606
# Epoch 46 Batch 1100 Loss 0.0322
# Epoch 46 Batch 1200 Loss 0.0394
# Epoch 46 Loss 0.0406
# Time taken for 1 epoch 73.30041360855103 sec
#
# Epoch 47 Batch 0 Loss 0.0297
# Epoch 47 Batch 100 Loss 0.0255
# Epoch 47 Batch 200 Loss 0.0191
# Epoch 47 Batch 300 Loss 0.0291
# Epoch 47 Batch 400 Loss 0.0396
# Epoch 47 Batch 500 Loss 0.0425
# Epoch 47 Batch 600 Loss 0.0286
# Epoch 47 Batch 700 Loss 0.0360
# Epoch 47 Batch 800 Loss 0.0358
# Epoch 47 Batch 900 Loss 0.0302
# Epoch 47 Batch 1000 Loss 0.0465
# Epoch 47 Batch 1100 Loss 0.0313
# Epoch 47 Batch 1200 Loss 0.0570
# Epoch 47 Loss 0.0402
# Time taken for 1 epoch 72.08391213417053 sec
#
# Epoch 48 Batch 0 Loss 0.0221
# Epoch 48 Batch 100 Loss 0.0381
# Epoch 48 Batch 200 Loss 0.0241
# Epoch 48 Batch 300 Loss 0.0245
# Epoch 48 Batch 400 Loss 0.0193
# Epoch 48 Batch 500 Loss 0.0388
# Epoch 48 Batch 600 Loss 0.0406
# Epoch 48 Batch 700 Loss 0.0377
# Epoch 48 Batch 800 Loss 0.0376
# Epoch 48 Batch 900 Loss 0.0195
# Epoch 48 Batch 1000 Loss 0.0420
# Epoch 48 Batch 1100 Loss 0.0343
# Epoch 48 Batch 1200 Loss 0.0536
# Epoch 48 Loss 0.0401
# Time taken for 1 epoch 73.13744711875916 sec
#
# Epoch 49 Batch 0 Loss 0.0206
# Epoch 49 Batch 100 Loss 0.0285
# Epoch 49 Batch 200 Loss 0.0280
# Epoch 49 Batch 300 Loss 0.0397
# Epoch 49 Batch 400 Loss 0.0386
# Epoch 49 Batch 500 Loss 0.0369
# Epoch 49 Batch 600 Loss 0.0425
# Epoch 49 Batch 700 Loss 0.0390
# Epoch 49 Batch 800 Loss 0.0404
# Epoch 49 Batch 900 Loss 0.0281
# Epoch 49 Batch 1000 Loss 0.0348
# Epoch 49 Batch 1100 Loss 0.0789
# Epoch 49 Batch 1200 Loss 0.0257
# Epoch 49 Loss 0.0393
# Time taken for 1 epoch 72.17815089225769 sec
#
# Epoch 50 Batch 0 Loss 0.0441
# Epoch 50 Batch 100 Loss 0.0476
# Epoch 50 Batch 200 Loss 0.0613
# Epoch 50 Batch 300 Loss 0.0241
# Epoch 50 Batch 400 Loss 0.0334
# Epoch 50 Batch 500 Loss 0.0491
# Epoch 50 Batch 600 Loss 0.0255
# Epoch 50 Batch 700 Loss 0.0456
# Epoch 50 Batch 800 Loss 0.0338
# Epoch 50 Batch 900 Loss 0.0266
# Epoch 50 Batch 1000 Loss 0.0438
# Epoch 50 Batch 1100 Loss 0.0331
# Epoch 50 Batch 1200 Loss 0.0657
# Epoch 50 Loss 0.0394
# Time taken for 1 epoch 73.50162482261658 sec
#
# Epoch 51 Batch 0 Loss 0.0280
# Epoch 51 Batch 100 Loss 0.0354
# Epoch 51 Batch 200 Loss 0.0323
# Epoch 51 Batch 300 Loss 0.0640
# Epoch 51 Batch 400 Loss 0.0419
# Epoch 51 Batch 500 Loss 0.0523
# Epoch 51 Batch 600 Loss 0.0584
# Epoch 51 Batch 700 Loss 0.0363
# Epoch 51 Batch 800 Loss 0.0268
# Epoch 51 Batch 900 Loss 0.0316
# Epoch 51 Batch 1000 Loss 0.0472
# Epoch 51 Batch 1100 Loss 0.0352
# Epoch 51 Batch 1200 Loss 0.0439
# Epoch 51 Loss 0.0385
# Time taken for 1 epoch 72.14831376075745 sec
#
# Epoch 52 Batch 0 Loss 0.0567
# Epoch 52 Batch 100 Loss 0.0650
# Epoch 52 Batch 200 Loss 0.0512
# Epoch 52 Batch 300 Loss 0.0301
# Epoch 52 Batch 400 Loss 0.0448
# Epoch 52 Batch 500 Loss 0.0219
# Epoch 52 Batch 600 Loss 0.0331
# Epoch 52 Batch 700 Loss 0.0485
# Epoch 52 Batch 800 Loss 0.0462
# Epoch 52 Batch 900 Loss 0.0331
# Epoch 52 Batch 1000 Loss 0.0458
# Epoch 52 Batch 1100 Loss 0.0789
# Epoch 52 Batch 1200 Loss 0.0385
# Epoch 52 Loss 0.0382
# Time taken for 1 epoch 73.48219704627991 sec
#
# Epoch 53 Batch 0 Loss 0.0262
# Epoch 53 Batch 100 Loss 0.0278
# Epoch 53 Batch 200 Loss 0.0343
# Epoch 53 Batch 300 Loss 0.0307
# Epoch 53 Batch 400 Loss 0.0376
# Epoch 53 Batch 500 Loss 0.0250
# Epoch 53 Batch 600 Loss 0.0541
# Epoch 53 Batch 700 Loss 0.0297
# Epoch 53 Batch 800 Loss 0.0376
# Epoch 53 Batch 900 Loss 0.0482
# Epoch 53 Batch 1000 Loss 0.0375
# Epoch 53 Batch 1100 Loss 0.0208
# Epoch 53 Batch 1200 Loss 0.0325
# Epoch 53 Loss 0.0381
# Time taken for 1 epoch 72.08837246894836 sec
#
# Epoch 54 Batch 0 Loss 0.0281
# Epoch 54 Batch 100 Loss 0.0326
# Epoch 54 Batch 200 Loss 0.0298
# Epoch 54 Batch 300 Loss 0.0398
# Epoch 54 Batch 400 Loss 0.0428
# Epoch 54 Batch 500 Loss 0.0369
# Epoch 54 Batch 600 Loss 0.0325
# Epoch 54 Batch 700 Loss 0.0381
# Epoch 54 Batch 800 Loss 0.0387
# Epoch 54 Batch 900 Loss 0.0421
# Epoch 54 Batch 1000 Loss 0.0604
# Epoch 54 Batch 1100 Loss 0.0181
# Epoch 54 Batch 1200 Loss 0.0300
# Epoch 54 Loss 0.0374
# Time taken for 1 epoch 73.26278614997864 sec
#
# Epoch 55 Batch 0 Loss 0.0254
# Epoch 55 Batch 100 Loss 0.0260
# Epoch 55 Batch 200 Loss 0.0189
# Epoch 55 Batch 300 Loss 0.0226
# Epoch 55 Batch 400 Loss 0.0411
# Epoch 55 Batch 500 Loss 0.0288
# Epoch 55 Batch 600 Loss 0.0220
# Epoch 55 Batch 700 Loss 0.0270
# Epoch 55 Batch 800 Loss 0.0432
# Epoch 55 Batch 900 Loss 0.0673
# Epoch 55 Batch 1000 Loss 0.0394
# Epoch 55 Batch 1100 Loss 0.0538
# Epoch 55 Batch 1200 Loss 0.0262
# Epoch 55 Loss 0.0370
# Time taken for 1 epoch 72.138920545578 sec
#
# Epoch 56 Batch 0 Loss 0.0270
# Epoch 56 Batch 100 Loss 0.0196
# Epoch 56 Batch 200 Loss 0.0278
# Epoch 56 Batch 300 Loss 0.0223
# Epoch 56 Batch 400 Loss 0.0293
# Epoch 56 Batch 500 Loss 0.0577
# Epoch 56 Batch 600 Loss 0.0357
# Epoch 56 Batch 700 Loss 0.0376
# Epoch 56 Batch 800 Loss 0.0226
# Epoch 56 Batch 900 Loss 0.0393
# Epoch 56 Batch 1000 Loss 0.0642
# Epoch 56 Batch 1100 Loss 0.0305
# Epoch 56 Batch 1200 Loss 0.0429
# Epoch 56 Loss 0.0371
# Time taken for 1 epoch 73.2693464756012 sec
#
# Epoch 57 Batch 0 Loss 0.0323
# Epoch 57 Batch 100 Loss 0.0206
# Epoch 57 Batch 200 Loss 0.0264
# Epoch 57 Batch 300 Loss 0.0636
# Epoch 57 Batch 400 Loss 0.0335
# Epoch 57 Batch 500 Loss 0.0266
# Epoch 57 Batch 600 Loss 0.0173
# Epoch 57 Batch 700 Loss 0.0542
# Epoch 57 Batch 800 Loss 0.0168
# Epoch 57 Batch 900 Loss 0.0363
# Epoch 57 Batch 1000 Loss 0.0226
# Epoch 57 Batch 1100 Loss 0.0326
# Epoch 57 Batch 1200 Loss 0.0474
# Epoch 57 Loss 0.0367
# Time taken for 1 epoch 72.12143087387085 sec
#
# Epoch 58 Batch 0 Loss 0.0246
# Epoch 58 Batch 100 Loss 0.0201
# Epoch 58 Batch 200 Loss 0.0135
# Epoch 58 Batch 300 Loss 0.0353
# Epoch 58 Batch 400 Loss 0.0360
# Epoch 58 Batch 500 Loss 0.0405
# Epoch 58 Batch 600 Loss 0.0251
# Epoch 58 Batch 700 Loss 0.0572
# Epoch 58 Batch 800 Loss 0.0360
# Epoch 58 Batch 900 Loss 0.0517
# Epoch 58 Batch 1000 Loss 0.0674
# Epoch 58 Batch 1100 Loss 0.0581
# Epoch 58 Batch 1200 Loss 0.0243
# Epoch 58 Loss 0.0365
# Time taken for 1 epoch 73.42968606948853 sec
#
# Epoch 59 Batch 0 Loss 0.0420
# Epoch 59 Batch 100 Loss 0.0550
# Epoch 59 Batch 200 Loss 0.0335
# Epoch 59 Batch 300 Loss 0.0408
# Epoch 59 Batch 400 Loss 0.0265
# Epoch 59 Batch 500 Loss 0.0214
# Epoch 59 Batch 600 Loss 0.0371
# Epoch 59 Batch 700 Loss 0.0252
# Epoch 59 Batch 800 Loss 0.0246
# Epoch 59 Batch 900 Loss 0.0461
# Epoch 59 Batch 1000 Loss 0.0158
# Epoch 59 Batch 1100 Loss 0.0485
# Epoch 59 Batch 1200 Loss 0.0725
# Epoch 59 Loss 0.0364
# Time taken for 1 epoch 72.1847312450409 sec
#
# Epoch 60 Batch 0 Loss 0.0256
# Epoch 60 Batch 100 Loss 0.0413
# Epoch 60 Batch 200 Loss 0.0197
# Epoch 60 Batch 300 Loss 0.0330
# Epoch 60 Batch 400 Loss 0.0432
# Epoch 60 Batch 500 Loss 0.0339
# Epoch 60 Batch 600 Loss 0.0267
# Epoch 60 Batch 700 Loss 0.0243
# Epoch 60 Batch 800 Loss 0.0401
# Epoch 60 Batch 900 Loss 0.0374
# Epoch 60 Batch 1000 Loss 0.0391
# Epoch 60 Batch 1100 Loss 0.0487
# Epoch 60 Batch 1200 Loss 0.0582
# Epoch 60 Loss 0.0353
# Time taken for 1 epoch 73.27455520629883 sec
#
# Epoch 61 Batch 0 Loss 0.0246
# Epoch 61 Batch 100 Loss 0.0222
# Epoch 61 Batch 200 Loss 0.0362
# Epoch 61 Batch 300 Loss 0.0487
# Epoch 61 Batch 400 Loss 0.0343
# Epoch 61 Batch 500 Loss 0.0269
# Epoch 61 Batch 600 Loss 0.0273
# Epoch 61 Batch 700 Loss 0.0247
# Epoch 61 Batch 800 Loss 0.0212
# Epoch 61 Batch 900 Loss 0.0399
# Epoch 61 Batch 1000 Loss 0.0329
# Epoch 61 Batch 1100 Loss 0.0293
# Epoch 61 Batch 1200 Loss 0.0379
# Epoch 61 Loss 0.0354
# Time taken for 1 epoch 72.04860663414001 sec
#
# Epoch 62 Batch 0 Loss 0.0386
# Epoch 62 Batch 100 Loss 0.0307
# Epoch 62 Batch 200 Loss 0.0230
# Epoch 62 Batch 300 Loss 0.0392
# Epoch 62 Batch 400 Loss 0.0441
# Epoch 62 Batch 500 Loss 0.0437
# Epoch 62 Batch 600 Loss 0.0291
# Epoch 62 Batch 700 Loss 0.0260
# Epoch 62 Batch 800 Loss 0.0298
# Epoch 62 Batch 900 Loss 0.0364
# Epoch 62 Batch 1000 Loss 0.0318
# Epoch 62 Batch 1100 Loss 0.0427
# Epoch 62 Batch 1200 Loss 0.0423
# Epoch 62 Loss 0.0359
# Time taken for 1 epoch 73.18275499343872 sec
#
# Epoch 63 Batch 0 Loss 0.0201
# Epoch 63 Batch 100 Loss 0.0246
# Epoch 63 Batch 200 Loss 0.0329
# Epoch 63 Batch 300 Loss 0.0358
# Epoch 63 Batch 400 Loss 0.0357
# Epoch 63 Batch 500 Loss 0.0329
# Epoch 63 Batch 600 Loss 0.0253
# Epoch 63 Batch 700 Loss 0.0492
# Epoch 63 Batch 800 Loss 0.0300
# Epoch 63 Batch 900 Loss 0.0422
# Epoch 63 Batch 1000 Loss 0.0400
# Epoch 63 Batch 1100 Loss 0.0666
# Epoch 63 Batch 1200 Loss 0.0739
# Epoch 63 Loss 0.0358
# Time taken for 1 epoch 72.10514569282532 sec
#
# Epoch 64 Batch 0 Loss 0.0300
# Epoch 64 Batch 100 Loss 0.0245
# Epoch 64 Batch 200 Loss 0.0407
# Epoch 64 Batch 300 Loss 0.0207
# Epoch 64 Batch 400 Loss 0.0308
# Epoch 64 Batch 500 Loss 0.0389
# Epoch 64 Batch 600 Loss 0.0266
# Epoch 64 Batch 700 Loss 0.0304
# Epoch 64 Batch 800 Loss 0.0426
# Epoch 64 Batch 900 Loss 0.0503
# Epoch 64 Batch 1000 Loss 0.0305
# Epoch 64 Batch 1100 Loss 0.0271
# Epoch 64 Batch 1200 Loss 0.0285
# Epoch 64 Loss 0.0348
# Time taken for 1 epoch 73.03361392021179 sec
#
# Epoch 65 Batch 0 Loss 0.0217
# Epoch 65 Batch 100 Loss 0.0269
# Epoch 65 Batch 200 Loss 0.0206
# Epoch 65 Batch 300 Loss 0.0175
# Epoch 65 Batch 400 Loss 0.0310
# Epoch 65 Batch 500 Loss 0.0319
# Epoch 65 Batch 600 Loss 0.0193
# Epoch 65 Batch 700 Loss 0.0381
# Epoch 65 Batch 800 Loss 0.0207
# Epoch 65 Batch 900 Loss 0.0511
# Epoch 65 Batch 1000 Loss 0.0174
# Epoch 65 Batch 1100 Loss 0.0571
# Epoch 65 Batch 1200 Loss 0.0238
# Epoch 65 Loss 0.0343
# Time taken for 1 epoch 72.14043498039246 sec
#
# Epoch 66 Batch 0 Loss 0.0241
# Epoch 66 Batch 100 Loss 0.0209
# Epoch 66 Batch 200 Loss 0.0347
# Epoch 66 Batch 300 Loss 0.0460
# Epoch 66 Batch 400 Loss 0.0286
# Epoch 66 Batch 500 Loss 0.0260
# Epoch 66 Batch 600 Loss 0.0277
# Epoch 66 Batch 700 Loss 0.0394
# Epoch 66 Batch 800 Loss 0.0305
# Epoch 66 Batch 900 Loss 0.0401
# Epoch 66 Batch 1000 Loss 0.0493
# Epoch 66 Batch 1100 Loss 0.0502
# Epoch 66 Batch 1200 Loss 0.0701
# Epoch 66 Loss 0.0341
# Time taken for 1 epoch 73.0815486907959 sec
#
# Epoch 67 Batch 0 Loss 0.0322
# Epoch 67 Batch 100 Loss 0.0297
# Epoch 67 Batch 200 Loss 0.0136
# Epoch 67 Batch 300 Loss 0.0363
# Epoch 67 Batch 400 Loss 0.0268
# Epoch 67 Batch 500 Loss 0.0403
# Epoch 67 Batch 600 Loss 0.0272
# Epoch 67 Batch 700 Loss 0.0463
# Epoch 67 Batch 800 Loss 0.0489
# Epoch 67 Batch 900 Loss 0.0596
# Epoch 67 Batch 1000 Loss 0.0481
# Epoch 67 Batch 1100 Loss 0.0272
# Epoch 67 Batch 1200 Loss 0.0209
# Epoch 67 Loss 0.0342
# Time taken for 1 epoch 72.05041265487671 sec
#
# Epoch 68 Batch 0 Loss 0.0191
# Epoch 68 Batch 100 Loss 0.0360
# Epoch 68 Batch 200 Loss 0.0458
# Epoch 68 Batch 300 Loss 0.0583
# Epoch 68 Batch 400 Loss 0.0411
# Epoch 68 Batch 500 Loss 0.0339
# Epoch 68 Batch 600 Loss 0.0291
# Epoch 68 Batch 700 Loss 0.0335
# Epoch 68 Batch 800 Loss 0.0383
# Epoch 68 Batch 900 Loss 0.0365
# Epoch 68 Batch 1000 Loss 0.0240
# Epoch 68 Batch 1100 Loss 0.0234
# Epoch 68 Batch 1200 Loss 0.0581
# Epoch 68 Loss 0.0341
# Time taken for 1 epoch 73.16395497322083 sec
#
# Epoch 69 Batch 0 Loss 0.0212
# Epoch 69 Batch 100 Loss 0.0362
# Epoch 69 Batch 200 Loss 0.0150
# Epoch 69 Batch 300 Loss 0.0229
# Epoch 69 Batch 400 Loss 0.0143
# Epoch 69 Batch 500 Loss 0.0368
# Epoch 69 Batch 600 Loss 0.0496
# Epoch 69 Batch 700 Loss 0.0309
# Epoch 69 Batch 800 Loss 0.0303
# Epoch 69 Batch 900 Loss 0.0432
# Epoch 69 Batch 1000 Loss 0.0326
# Epoch 69 Batch 1100 Loss 0.0452
# Epoch 69 Batch 1200 Loss 0.0359
# Epoch 69 Loss 0.0338
# Time taken for 1 epoch 71.83087611198425 sec
#
# Epoch 70 Batch 0 Loss 0.0189
# Epoch 70 Batch 100 Loss 0.0334
# Epoch 70 Batch 200 Loss 0.0156
# Epoch 70 Batch 300 Loss 0.0483
# Epoch 70 Batch 400 Loss 0.0193
# Epoch 70 Batch 500 Loss 0.0361
# Epoch 70 Batch 600 Loss 0.0272
# Epoch 70 Batch 700 Loss 0.0454
# Epoch 70 Batch 800 Loss 0.0489
# Epoch 70 Batch 900 Loss 0.0228
# Epoch 70 Batch 1000 Loss 0.0447
# Epoch 70 Batch 1100 Loss 0.0427
# Epoch 70 Batch 1200 Loss 0.0379
# Epoch 70 Loss 0.0339
# Time taken for 1 epoch 73.07154321670532 sec
#
# Epoch 71 Batch 0 Loss 0.0215
# Epoch 71 Batch 100 Loss 0.0189
# Epoch 71 Batch 200 Loss 0.0296
# Epoch 71 Batch 300 Loss 0.0257
# Epoch 71 Batch 400 Loss 0.0205
# Epoch 71 Batch 500 Loss 0.0237
# Epoch 71 Batch 600 Loss 0.0255
# Epoch 71 Batch 700 Loss 0.0342
# Epoch 71 Batch 800 Loss 0.0358
# Epoch 71 Batch 900 Loss 0.0361
# Epoch 71 Batch 1000 Loss 0.0396
# Epoch 71 Batch 1100 Loss 0.0530
# Epoch 71 Batch 1200 Loss 0.0461
# Epoch 71 Loss 0.0335
# Time taken for 1 epoch 72.00734543800354 sec
#
# Epoch 72 Batch 0 Loss 0.0270
# Epoch 72 Batch 100 Loss 0.0386
# Epoch 72 Batch 200 Loss 0.0211
# Epoch 72 Batch 300 Loss 0.0371
# Epoch 72 Batch 400 Loss 0.0337
# Epoch 72 Batch 500 Loss 0.0294
# Epoch 72 Batch 600 Loss 0.0228
# Epoch 72 Batch 700 Loss 0.0151
# Epoch 72 Batch 800 Loss 0.0234
# Epoch 72 Batch 900 Loss 0.0246
# Epoch 72 Batch 1000 Loss 0.0369
# Epoch 72 Batch 1100 Loss 0.0444
# Epoch 72 Batch 1200 Loss 0.0284
# Epoch 72 Loss 0.0332
# Time taken for 1 epoch 73.14650464057922 sec
#
# Epoch 73 Batch 0 Loss 0.0306
# Epoch 73 Batch 100 Loss 0.0166
# Epoch 73 Batch 200 Loss 0.0185
# Epoch 73 Batch 300 Loss 0.0223
# Epoch 73 Batch 400 Loss 0.0284
# Epoch 73 Batch 500 Loss 0.0618
# Epoch 73 Batch 600 Loss 0.0223
# Epoch 73 Batch 700 Loss 0.0203
# Epoch 73 Batch 800 Loss 0.0299
# Epoch 73 Batch 900 Loss 0.0503
# Epoch 73 Batch 1000 Loss 0.0275
# Epoch 73 Batch 1100 Loss 0.0421
# Epoch 73 Batch 1200 Loss 0.0576
# Epoch 73 Loss 0.0333
# Time taken for 1 epoch 72.39710855484009 sec
#
# Epoch 74 Batch 0 Loss 0.0211
# Epoch 74 Batch 100 Loss 0.0290
# Epoch 74 Batch 200 Loss 0.0386
# Epoch 74 Batch 300 Loss 0.0191
# Epoch 74 Batch 400 Loss 0.0298
# Epoch 74 Batch 500 Loss 0.0322
# Epoch 74 Batch 600 Loss 0.0368
# Epoch 74 Batch 700 Loss 0.0113
# Epoch 74 Batch 800 Loss 0.0422
# Epoch 74 Batch 900 Loss 0.0284
# Epoch 74 Batch 1000 Loss 0.0379
# Epoch 74 Batch 1100 Loss 0.0321
# Epoch 74 Batch 1200 Loss 0.0372
# Epoch 74 Loss 0.0327
# Time taken for 1 epoch 74.23059272766113 sec
#
# Epoch 75 Batch 0 Loss 0.0122
# Epoch 75 Batch 100 Loss 0.0251
# Epoch 75 Batch 200 Loss 0.0115
# Epoch 75 Batch 300 Loss 0.0297
# Epoch 75 Batch 400 Loss 0.0168
# Epoch 75 Batch 500 Loss 0.0284
# Epoch 75 Batch 600 Loss 0.0351
# Epoch 75 Batch 700 Loss 0.0232
# Epoch 75 Batch 800 Loss 0.0369
# Epoch 75 Batch 900 Loss 0.0437
# Epoch 75 Batch 1000 Loss 0.0298
# Epoch 75 Batch 1100 Loss 0.0352
# Epoch 75 Batch 1200 Loss 0.0373
# Epoch 75 Loss 0.0329
# Time taken for 1 epoch 72.94284200668335 sec
#
# Epoch 76 Batch 0 Loss 0.0238
# Epoch 76 Batch 100 Loss 0.0442
# Epoch 76 Batch 200 Loss 0.0226
# Epoch 76 Batch 300 Loss 0.0310
# Epoch 76 Batch 400 Loss 0.0382
# Epoch 76 Batch 500 Loss 0.0275
# Epoch 76 Batch 600 Loss 0.0222
# Epoch 76 Batch 700 Loss 0.0400
# Epoch 76 Batch 800 Loss 0.0465
# Epoch 76 Batch 900 Loss 0.0392
# Epoch 76 Batch 1000 Loss 0.0326
# Epoch 76 Batch 1100 Loss 0.0447
# Epoch 76 Batch 1200 Loss 0.0244
# Epoch 76 Loss 0.0329
# Time taken for 1 epoch 74.10657262802124 sec
#
# Epoch 77 Batch 0 Loss 0.0338
# Epoch 77 Batch 100 Loss 0.0314
# Epoch 77 Batch 200 Loss 0.0379
# Epoch 77 Batch 300 Loss 0.0290
# Epoch 77 Batch 400 Loss 0.0239
# Epoch 77 Batch 500 Loss 0.0302
# Epoch 77 Batch 600 Loss 0.0203
# Epoch 77 Batch 700 Loss 0.0282
# Epoch 77 Batch 800 Loss 0.0247
# Epoch 77 Batch 900 Loss 0.0530
# Epoch 77 Batch 1000 Loss 0.0219
# Epoch 77 Batch 1100 Loss 0.0511
# Epoch 77 Batch 1200 Loss 0.0267
# Epoch 77 Loss 0.0323
# Time taken for 1 epoch 72.88052177429199 sec
#
# Epoch 78 Batch 0 Loss 0.0154
# Epoch 78 Batch 100 Loss 0.0224
# Epoch 78 Batch 200 Loss 0.0322
# Epoch 78 Batch 300 Loss 0.0183
# Epoch 78 Batch 400 Loss 0.0325
# Epoch 78 Batch 500 Loss 0.0159
# Epoch 78 Batch 600 Loss 0.0325
# Epoch 78 Batch 700 Loss 0.0239
# Epoch 78 Batch 800 Loss 0.0487
# Epoch 78 Batch 900 Loss 0.0340
# Epoch 78 Batch 1000 Loss 0.0396
# Epoch 78 Batch 1100 Loss 0.0378
# Epoch 78 Batch 1200 Loss 0.0435
# Epoch 78 Loss 0.0326
# Time taken for 1 epoch 74.22760319709778 sec
#
# Epoch 79 Batch 0 Loss 0.0256
# Epoch 79 Batch 100 Loss 0.0212
# Epoch 79 Batch 200 Loss 0.0364
# Epoch 79 Batch 300 Loss 0.0297
# Epoch 79 Batch 400 Loss 0.0281
# Epoch 79 Batch 500 Loss 0.0314
# Epoch 79 Batch 600 Loss 0.0421
# Epoch 79 Batch 700 Loss 0.0186
# Epoch 79 Batch 800 Loss 0.0387
# Epoch 79 Batch 900 Loss 0.0289
# Epoch 79 Batch 1000 Loss 0.0280
# Epoch 79 Batch 1100 Loss 0.0381
# Epoch 79 Batch 1200 Loss 0.0457
# Epoch 79 Loss 0.0320
# Time taken for 1 epoch 72.7825186252594 sec
#
# Epoch 80 Batch 0 Loss 0.0158
# Epoch 80 Batch 100 Loss 0.0161
# Epoch 80 Batch 200 Loss 0.0283
# Epoch 80 Batch 300 Loss 0.0267
# Epoch 80 Batch 400 Loss 0.0208
# Epoch 80 Batch 500 Loss 0.0406
# Epoch 80 Batch 600 Loss 0.0384
# Epoch 80 Batch 700 Loss 0.0277
# Epoch 80 Batch 800 Loss 0.0152
# Epoch 80 Batch 900 Loss 0.0477
# Epoch 80 Batch 1000 Loss 0.0352
# Epoch 80 Batch 1100 Loss 0.0256
# Epoch 80 Batch 1200 Loss 0.0452
# Epoch 80 Loss 0.0324
# Time taken for 1 epoch 73.88207745552063 sec
#
# Epoch 81 Batch 0 Loss 0.0181
# Epoch 81 Batch 100 Loss 0.0298
# Epoch 81 Batch 200 Loss 0.0246
# Epoch 81 Batch 300 Loss 0.0172
# Epoch 81 Batch 400 Loss 0.0230
# Epoch 81 Batch 500 Loss 0.0295
# Epoch 81 Batch 600 Loss 0.0389
# Epoch 81 Batch 700 Loss 0.0255
# Epoch 81 Batch 800 Loss 0.0428
# Epoch 81 Batch 900 Loss 0.0361
# Epoch 81 Batch 1000 Loss 0.0423
# Epoch 81 Batch 1100 Loss 0.0329
# Epoch 81 Batch 1200 Loss 0.0355
# Epoch 81 Loss 0.0323
# Time taken for 1 epoch 72.9216730594635 sec
#
# Epoch 82 Batch 0 Loss 0.0217
# Epoch 82 Batch 100 Loss 0.0278
# Epoch 82 Batch 200 Loss 0.0159
# Epoch 82 Batch 300 Loss 0.0396
# Epoch 82 Batch 400 Loss 0.0368
# Epoch 82 Batch 500 Loss 0.0137
# Epoch 82 Batch 600 Loss 0.0435
# Epoch 82 Batch 700 Loss 0.0141
# Epoch 82 Batch 800 Loss 0.0243
# Epoch 82 Batch 900 Loss 0.0230
# Epoch 82 Batch 1000 Loss 0.0203
# Epoch 82 Batch 1100 Loss 0.0336
# Epoch 82 Batch 1200 Loss 0.0410
# Epoch 82 Loss 0.0318
# Time taken for 1 epoch 73.90750670433044 sec
#
# Epoch 83 Batch 0 Loss 0.0386
# Epoch 83 Batch 100 Loss 0.0355
# Epoch 83 Batch 200 Loss 0.0258
# Epoch 83 Batch 300 Loss 0.0243
# Epoch 83 Batch 400 Loss 0.0231
# Epoch 83 Batch 500 Loss 0.0537
# Epoch 83 Batch 600 Loss 0.0311
# Epoch 83 Batch 700 Loss 0.0360
# Epoch 83 Batch 800 Loss 0.0488
# Epoch 83 Batch 900 Loss 0.0537
# Epoch 83 Batch 1000 Loss 0.0381
# Epoch 83 Batch 1100 Loss 0.0627
# Epoch 83 Batch 1200 Loss 0.0399
# Epoch 83 Loss 0.0314
# Time taken for 1 epoch 72.85775828361511 sec
#
# Epoch 84 Batch 0 Loss 0.0317
# Epoch 84 Batch 100 Loss 0.0258
# Epoch 84 Batch 200 Loss 0.0256
# Epoch 84 Batch 300 Loss 0.0179
# Epoch 84 Batch 400 Loss 0.0397
# Epoch 84 Batch 500 Loss 0.0191
# Epoch 84 Batch 600 Loss 0.0395
# Epoch 84 Batch 700 Loss 0.0417
# Epoch 84 Batch 800 Loss 0.0330
# Epoch 84 Batch 900 Loss 0.0318
# Epoch 84 Batch 1000 Loss 0.0460
# Epoch 84 Batch 1100 Loss 0.0237
# Epoch 84 Batch 1200 Loss 0.0671
# Epoch 84 Loss 0.0318
# Time taken for 1 epoch 74.15753769874573 sec
#
# Epoch 85 Batch 0 Loss 0.0162
# Epoch 85 Batch 100 Loss 0.0299
# Epoch 85 Batch 200 Loss 0.0179
# Epoch 85 Batch 300 Loss 0.0381
# Epoch 85 Batch 400 Loss 0.0220
# Epoch 85 Batch 500 Loss 0.0183
# Epoch 85 Batch 600 Loss 0.0387
# Epoch 85 Batch 700 Loss 0.0275
# Epoch 85 Batch 800 Loss 0.0317
# Epoch 85 Batch 900 Loss 0.0206
# Epoch 85 Batch 1000 Loss 0.0308
# Epoch 85 Batch 1100 Loss 0.0227
# Epoch 85 Batch 1200 Loss 0.0375
# Epoch 85 Loss 0.0319
# Time taken for 1 epoch 72.84961318969727 sec
#
# Epoch 86 Batch 0 Loss 0.0262
# Epoch 86 Batch 100 Loss 0.0356
# Epoch 86 Batch 200 Loss 0.0320
# Epoch 86 Batch 300 Loss 0.0376
# Epoch 86 Batch 400 Loss 0.0345
# Epoch 86 Batch 500 Loss 0.0301
# Epoch 86 Batch 600 Loss 0.0276
# Epoch 86 Batch 700 Loss 0.0351
# Epoch 86 Batch 800 Loss 0.0149
# Epoch 86 Batch 900 Loss 0.0234
# Epoch 86 Batch 1000 Loss 0.0407
# Epoch 86 Batch 1100 Loss 0.0352
# Epoch 86 Batch 1200 Loss 0.0463
# Epoch 86 Loss 0.0314
# Time taken for 1 epoch 74.02526211738586 sec
#
# Epoch 87 Batch 0 Loss 0.0284
# Epoch 87 Batch 100 Loss 0.0070
# Epoch 87 Batch 200 Loss 0.0394
# Epoch 87 Batch 300 Loss 0.0348
# Epoch 87 Batch 400 Loss 0.0305
# Epoch 87 Batch 500 Loss 0.0531
# Epoch 87 Batch 600 Loss 0.0147
# Epoch 87 Batch 700 Loss 0.0184
# Epoch 87 Batch 800 Loss 0.0361
# Epoch 87 Batch 900 Loss 0.0330
# Epoch 87 Batch 1000 Loss 0.0262
# Epoch 87 Batch 1100 Loss 0.0227
# Epoch 87 Batch 1200 Loss 0.0322
# Epoch 87 Loss 0.0312
# Time taken for 1 epoch 72.91126155853271 sec
#
# Epoch 88 Batch 0 Loss 0.0257
# Epoch 88 Batch 100 Loss 0.0249
# Epoch 88 Batch 200 Loss 0.0347
# Epoch 88 Batch 300 Loss 0.0292
# Epoch 88 Batch 400 Loss 0.0251
# Epoch 88 Batch 500 Loss 0.0396
# Epoch 88 Batch 600 Loss 0.0221
# Epoch 88 Batch 700 Loss 0.0296
# Epoch 88 Batch 800 Loss 0.0309
# Epoch 88 Batch 900 Loss 0.0487
# Epoch 88 Batch 1000 Loss 0.0543
# Epoch 88 Batch 1100 Loss 0.0482
# Epoch 88 Batch 1200 Loss 0.0420
# Epoch 88 Loss 0.0309
# Time taken for 1 epoch 74.21344017982483 sec
#
# Epoch 89 Batch 0 Loss 0.0086
# Epoch 89 Batch 100 Loss 0.0208
# Epoch 89 Batch 200 Loss 0.0445
# Epoch 89 Batch 300 Loss 0.0254
# Epoch 89 Batch 400 Loss 0.0546
# Epoch 89 Batch 500 Loss 0.0263
# Epoch 89 Batch 600 Loss 0.0225
# Epoch 89 Batch 700 Loss 0.0287
# Epoch 89 Batch 800 Loss 0.0416
# Epoch 89 Batch 900 Loss 0.0122
# Epoch 89 Batch 1000 Loss 0.0476
# Epoch 89 Batch 1100 Loss 0.0287
# Epoch 89 Batch 1200 Loss 0.0229
# Epoch 89 Loss 0.0303
# Time taken for 1 epoch 72.88254690170288 sec
#
# Epoch 90 Batch 0 Loss 0.0159
# Epoch 90 Batch 100 Loss 0.0253
# Epoch 90 Batch 200 Loss 0.0183
# Epoch 90 Batch 300 Loss 0.0490
# Epoch 90 Batch 400 Loss 0.0216
# Epoch 90 Batch 500 Loss 0.0151
# Epoch 90 Batch 600 Loss 0.0324
# Epoch 90 Batch 700 Loss 0.0217
# Epoch 90 Batch 800 Loss 0.0374
# Epoch 90 Batch 900 Loss 0.0247
# Epoch 90 Batch 1000 Loss 0.0263
# Epoch 90 Batch 1100 Loss 0.0280
# Epoch 90 Batch 1200 Loss 0.0537
# Epoch 90 Loss 0.0311
# Time taken for 1 epoch 73.90678024291992 sec
#
# Epoch 91 Batch 0 Loss 0.0141
# Epoch 91 Batch 100 Loss 0.0233
# Epoch 91 Batch 200 Loss 0.0273
# Epoch 91 Batch 300 Loss 0.0234
# Epoch 91 Batch 400 Loss 0.0335
# Epoch 91 Batch 500 Loss 0.0244
# Epoch 91 Batch 600 Loss 0.0271
# Epoch 91 Batch 700 Loss 0.0461
# Epoch 91 Batch 800 Loss 0.0380
# Epoch 91 Batch 900 Loss 0.0612
# Epoch 91 Batch 1000 Loss 0.0480
# Epoch 91 Batch 1100 Loss 0.0381
# Epoch 91 Batch 1200 Loss 0.0449
# Epoch 91 Loss 0.0311
# Time taken for 1 epoch 72.89472246170044 sec
#
# Epoch 92 Batch 0 Loss 0.0192
# Epoch 92 Batch 100 Loss 0.0201
# Epoch 92 Batch 200 Loss 0.0417
# Epoch 92 Batch 300 Loss 0.0243
# Epoch 92 Batch 400 Loss 0.0261
# Epoch 92 Batch 500 Loss 0.0195
# Epoch 92 Batch 600 Loss 0.0206
# Epoch 92 Batch 700 Loss 0.0529
# Epoch 92 Batch 800 Loss 0.0340
# Epoch 92 Batch 900 Loss 0.0367
# Epoch 92 Batch 1000 Loss 0.0394
# Epoch 92 Batch 1100 Loss 0.0334
# Epoch 92 Batch 1200 Loss 0.0237
# Epoch 92 Loss 0.0309
# Time taken for 1 epoch 74.20280933380127 sec
#
# Epoch 93 Batch 0 Loss 0.0387
# Epoch 93 Batch 100 Loss 0.0270
# Epoch 93 Batch 200 Loss 0.0136
# Epoch 93 Batch 300 Loss 0.0126
# Epoch 93 Batch 400 Loss 0.0197
# Epoch 93 Batch 500 Loss 0.0373
# Epoch 93 Batch 600 Loss 0.0459
# Epoch 93 Batch 700 Loss 0.0371
# Epoch 93 Batch 800 Loss 0.0417
# Epoch 93 Batch 900 Loss 0.0284
# Epoch 93 Batch 1000 Loss 0.0167
# Epoch 93 Batch 1100 Loss 0.0443
# Epoch 93 Batch 1200 Loss 0.0334
# Epoch 93 Loss 0.0306
# Time taken for 1 epoch 72.80149388313293 sec
#
# Epoch 94 Batch 0 Loss 0.0194
# Epoch 94 Batch 100 Loss 0.0085
# Epoch 94 Batch 200 Loss 0.0167
# Epoch 94 Batch 300 Loss 0.0245
# Epoch 94 Batch 400 Loss 0.0188
# Epoch 94 Batch 500 Loss 0.0317
# Epoch 94 Batch 600 Loss 0.0295
# Epoch 94 Batch 700 Loss 0.0286
# Epoch 94 Batch 800 Loss 0.0249
# Epoch 94 Batch 900 Loss 0.0370
# Epoch 94 Batch 1000 Loss 0.0341
# Epoch 94 Batch 1100 Loss 0.0255
# Epoch 94 Batch 1200 Loss 0.0339
# Epoch 94 Loss 0.0304
# Time taken for 1 epoch 74.10436415672302 sec
#
# Epoch 95 Batch 0 Loss 0.0161
# Epoch 95 Batch 100 Loss 0.0228
# Epoch 95 Batch 200 Loss 0.0139
# Epoch 95 Batch 300 Loss 0.0359
# Epoch 95 Batch 400 Loss 0.0291
# Epoch 95 Batch 500 Loss 0.0241
# Epoch 95 Batch 600 Loss 0.0379
# Epoch 95 Batch 700 Loss 0.0264
# Epoch 95 Batch 800 Loss 0.0256
# Epoch 95 Batch 900 Loss 0.0215
# Epoch 95 Batch 1000 Loss 0.0269
# Epoch 95 Batch 1100 Loss 0.0382
# Epoch 95 Batch 1200 Loss 0.0492
# Epoch 95 Loss 0.0302
# Time taken for 1 epoch 72.92206072807312 sec
#
# Epoch 96 Batch 0 Loss 0.0397
# Epoch 96 Batch 100 Loss 0.0120
# Epoch 96 Batch 200 Loss 0.0222
# Epoch 96 Batch 300 Loss 0.0215
# Epoch 96 Batch 400 Loss 0.0226
# Epoch 96 Batch 500 Loss 0.0214
# Epoch 96 Batch 600 Loss 0.0296
# Epoch 96 Batch 700 Loss 0.0353
# Epoch 96 Batch 800 Loss 0.0361
# Epoch 96 Batch 900 Loss 0.0507
# Epoch 96 Batch 1000 Loss 0.0166
# Epoch 96 Batch 1100 Loss 0.0229
# Epoch 96 Batch 1200 Loss 0.0285
# Epoch 96 Loss 0.0304
# Time taken for 1 epoch 74.09485030174255 sec
#
# Epoch 97 Batch 0 Loss 0.0237
# Epoch 97 Batch 100 Loss 0.0349
# Epoch 97 Batch 200 Loss 0.0272
# Epoch 97 Batch 300 Loss 0.0266
# Epoch 97 Batch 400 Loss 0.0300
# Epoch 97 Batch 500 Loss 0.0191
# Epoch 97 Batch 600 Loss 0.0179
# Epoch 97 Batch 700 Loss 0.0236
# Epoch 97 Batch 800 Loss 0.0469
# Epoch 97 Batch 900 Loss 0.0295
# Epoch 97 Batch 1000 Loss 0.0315
# Epoch 97 Batch 1100 Loss 0.0548
# Epoch 97 Batch 1200 Loss 0.0368
# Epoch 97 Loss 0.0303
# Time taken for 1 epoch 73.0981593132019 sec
#
# Epoch 98 Batch 0 Loss 0.0140
# Epoch 98 Batch 100 Loss 0.0258
# Epoch 98 Batch 200 Loss 0.0233
# Epoch 98 Batch 300 Loss 0.0289
# Epoch 98 Batch 400 Loss 0.0214
# Epoch 98 Batch 500 Loss 0.0215
# Epoch 98 Batch 600 Loss 0.0458
# Epoch 98 Batch 700 Loss 0.0241
# Epoch 98 Batch 800 Loss 0.0282
# Epoch 98 Batch 900 Loss 0.0277
# Epoch 98 Batch 1000 Loss 0.0478
# Epoch 98 Batch 1100 Loss 0.0247
# Epoch 98 Batch 1200 Loss 0.0374
# Epoch 98 Loss 0.0305
# Time taken for 1 epoch 74.07482266426086 sec
#
# Epoch 99 Batch 0 Loss 0.0158
# Epoch 99 Batch 100 Loss 0.0196
# Epoch 99 Batch 200 Loss 0.0257
# Epoch 99 Batch 300 Loss 0.0308
# Epoch 99 Batch 400 Loss 0.0286
# Epoch 99 Batch 500 Loss 0.0146
# Epoch 99 Batch 600 Loss 0.0204
# Epoch 99 Batch 700 Loss 0.0285
# Epoch 99 Batch 800 Loss 0.0415
# Epoch 99 Batch 900 Loss 0.0207
# Epoch 99 Batch 1000 Loss 0.0226
# Epoch 99 Batch 1100 Loss 0.0489
# Epoch 99 Batch 1200 Loss 0.0392
# Epoch 99 Loss 0.0302
# Time taken for 1 epoch 73.0620059967041 sec
#
# Epoch 100 Batch 0 Loss 0.0224
# Epoch 100 Batch 100 Loss 0.0178
# Epoch 100 Batch 200 Loss 0.0113
# Epoch 100 Batch 300 Loss 0.0547
# Epoch 100 Batch 400 Loss 0.0138
# Epoch 100 Batch 500 Loss 0.0234
# Epoch 100 Batch 600 Loss 0.0298
# Epoch 100 Batch 700 Loss 0.0293
# Epoch 100 Batch 800 Loss 0.0348
# Epoch 100 Batch 900 Loss 0.0091
# Epoch 100 Batch 1000 Loss 0.0246
# Epoch 100 Batch 1100 Loss 0.0502
# Epoch 100 Batch 1200 Loss 0.0548
# Epoch 100 Loss 0.0302
# Time taken for 1 epoch 74.00286889076233 sec

# %% [markdown]
# ## Translate
#
# * The evaluate function is similar to the training loop, except we don't use *teacher forcing* here. The input to the decoder at each time step is its previous predictions along with the hidden state and the encoder output.
# * Stop predicting when the model predicts the *end token*.
# * And store the *attention weights for every time step*.
#
# Note: The encoder output is calculated only once for one input.

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)
  result = ''

  hidden = [tf.zeros((1, units))]
  enc_hidden = encoder(inputs, hidden[0])

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden = decoder(dec_input, dec_hidden)

    # storing the attention weights to plot later on
    predicted_id = tf.argmax(predictions[0]).numpy()
    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence

# %%
def translate(sentence):
  result, sentence = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

# %% [markdown]
# ## Restore the latest checkpoint and test

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('Здесь хорошо.')
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: it's good here . <end>

# %%
translate('Я не смогу поехать.')
# Out:
# Input: <start> я не смогу поехать . <end>
# Predicted translation: i can't go . <end>

# %%
translate(u'Вы еще дома?')
# Out:
# Input: <start> вы еще дома ? <end>
# Predicted translation: are you still home ? <end>

# %%
translate(u'Вы все еще дома?')
# Out:
# Input: <start> вы все еще дома ? <end>
# Predicted translation: are you still at home ? <end>

# %%
translate(u'Попробуй сделать это.')
# Out:
# Input: <start> попробуй сделать это . <end>
# Predicted translation: try to do that . <end>

# %%
translate(u'Я люблю, когда идет снег.') # i love hot weather - ошибка перевода
# Out:
# Input: <start> я люблю , когда идет снег . <end>
# Predicted translation: i love hot weather . <end>

# %%
translate(u'Я никогда такого не делаю.')
# Out:
# Input: <start> я никогда такого не делаю . <end>
# Predicted translation: i never do that . <end>

# %%
translate(u'Какие ваши доказательства.')
# Out:
# Input: <start> какие ваши доказательства . <end>
# Predicted translation: your proof is low . <end>

# %%
translate(u'Руки вверх')
# Out:
# Input: <start> руки вверх <end>
# Predicted translation: hands up . <end>

# %% [markdown]
# Получился довольно таки сносный перевод, но маловат словарь.
