# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavel184/NLP_basic_course/blob/Homework_lesson_11/Homework_lesson_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### HOMEWORK_LESSON_11

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %% [markdown]
# ## Download and prepare the dataset
#
# We'll use a language dataset provided by http://www.manythings.org/anki/

# %%
# !wget http://www.manythings.org/anki/rus-eng.zip
# Out:
# --2021-12-10 07:20:40--  http://www.manythings.org/anki/rus-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 104.21.92.44, 172.67.186.54, 2606:4700:3033::ac43:ba36, ...
# Connecting to www.manythings.org (www.manythings.org)|104.21.92.44|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14611166 (14M) [application/zip]
# Saving to: ‘rus-eng.zip’
#
# rus-eng.zip         100%[===================>]  13.93M  17.3MB/s    in 0.8s
#
# 2021-12-10 07:20:41 (17.3 MB/s) - ‘rus-eng.zip’ saved [14611166/14611166]

# %%
# !mkdir rus-eng
# !unzip rus-eng.zip -d rus-eng/
# Out:
# Archive:  rus-eng.zip
#   inflating: rus-eng/rus.txt
#   inflating: rus-eng/_about.txt

# %%
# !ls /content/rus-eng/ -lah
# Out:
# total 70M
# drwxr-xr-x 2 root root 4.0K Dec 10 07:20 .
# drwxr-xr-x 1 root root 4.0K Dec 10 07:20 ..
# -rw-r--r-- 1 root root 1.5K Nov 29 01:09 _about.txt
# -rw-r--r-- 1 root root  70M Nov 29 01:09 rus.txt

# %%
# Download the file
path_to_file = "/content/rus-eng/rus.txt"

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
preprocess_sentence("I can't go.")
# Out:
# "<start> i can't go . <end>"

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENG, RUS]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, ru = create_dataset(path_to_file, None)
print(en[-1])
print(ru[-1])
# Out:
# <start> doubtless there exists in this world precisely the right woman for any given man to marry and vice versa but when you consider that a human being has the opportunity of being acquainted with only a few hundred people , and out of the few hundred that there are but a dozen or less whom he knows intimately , and out of the dozen , one or two friends at most , it will easily be seen , when we remember the number of millions who inhabit this world , that probably , since the earth was created , the right man has never yet met the right woman . <end>
# <start> несомненно , для каждого мужчины в этом мире где то есть подходящая женщина , которая может стать ему женой , обратное верно и для женщин . но если учесть , что у человека может быть максимум несколько сотен знакомых , из которых лишь дюжина , а то и меньше , тех , кого он знает близко , а из этой дюжины у него один или от силы два друга , то можно легко увидеть , что с уч том миллионов живущих на земле людей , ни один подходящий мужчина , возможно , ещ не встретил подходящую женщину . <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### Limit the size of the dataset to experiment faster (optional)

# %%
len(en), len(ru)
# Out:
# (438015, 438015)

# %%
# Try experimenting with the size of that dataset
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 80000 80000 20000 20000

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 4 ----> я
# 55 ----> хочу
# 8 ----> это
# 832 ----> исправить
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 4 ----> i
# 45 ----> want
# 11 ----> to
# 248 ----> fix
# 18 ----> that
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# ### Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 15]), TensorShape([64, 11]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.lstm = tf.keras.layers.LSTM(self.enc_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    

  def call(self, x, hidden):
    x = self.embedding(x)
    output_gru, state_gru = self.gru(x, initial_state = hidden)
    out1, out2, out3 = self.lstm(x, initial_state = [hidden, hidden]) # Добавил LSTM
    state = (state_gru + out3)/2 # Добавил усреднение эмбендингов
    output = (output_gru + out1)/2 # Добавил усреднение эмбендингов
    return output, state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder output shape: (batch size, sequence length, units) (64, 15, 1024)
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, query, values):
    # query hidden state shape == (batch_size, hidden size)
    # query_with_time_axis shape == (batch_size, 1, hidden size)
    # values shape == (batch_size, max_len, hidden size)
    # we are doing this to broadcast addition along the time axis to calculate the score
    query_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.relu( # tanh -> relu
        self.W1(query_with_time_axis) + self.W2(values)))
    
    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (64, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (64, 15, 1)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.lstm = tf.keras.layers.LSTM(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

    # used for attention
    self.attention = BahdanauAttention(self.dec_units)

  def call(self, x, hidden, enc_output):
    # enc_output shape == (batch_size, max_length, hidden_size)
    context_vector, attention_weights = self.attention(hidden, enc_output)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # passing the concatenated vector to the GRU
    output_gru, state_gru = self.gru(x, initial_state=hidden)

    # passing the concatenated vector to the LSTM
    out1, out2, out3 = self.lstm(x, initial_state=[hidden,hidden]) # Добавил LSTM

    output = (output_gru + out1) / 2 # Добавил усреднение эмбендингов
    state = (state_gru + out3) / 2

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden, sample_output)

print ('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (64, 7316)

# %% [markdown]
# ## Define the optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoints (Object-based saving)

# %%
checkpoint_dir = './training_attention_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_output, enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 100

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.5880
# Epoch 1 Batch 100 Loss 2.0341
# Epoch 1 Batch 200 Loss 1.6856
# Epoch 1 Batch 300 Loss 1.5688
# Epoch 1 Batch 400 Loss 1.5349
# Epoch 1 Batch 500 Loss 1.3816
# Epoch 1 Batch 600 Loss 1.4062
# Epoch 1 Batch 700 Loss 1.4568
# Epoch 1 Batch 800 Loss 1.3245
# Epoch 1 Batch 900 Loss 1.1574
# Epoch 1 Batch 1000 Loss 1.2857
# Epoch 1 Batch 1100 Loss 1.1058
# Epoch 1 Batch 1200 Loss 1.0946
# Epoch 1 Loss 1.4869
# Time taken for 1 epoch 137.11655974388123 sec
#
# Epoch 2 Batch 0 Loss 0.9869
# Epoch 2 Batch 100 Loss 1.0009
# Epoch 2 Batch 200 Loss 0.9372
# Epoch 2 Batch 300 Loss 0.8703
# Epoch 2 Batch 400 Loss 0.9392
# Epoch 2 Batch 500 Loss 0.9118
# Epoch 2 Batch 600 Loss 0.8792
# Epoch 2 Batch 700 Loss 0.7091
# Epoch 2 Batch 800 Loss 0.7309
# Epoch 2 Batch 900 Loss 0.6628
# Epoch 2 Batch 1000 Loss 0.6058
# Epoch 2 Batch 1100 Loss 0.5331
# Epoch 2 Batch 1200 Loss 0.7223
# Epoch 2 Loss 0.8137
# Time taken for 1 epoch 111.48747777938843 sec
#
# Epoch 3 Batch 0 Loss 0.4593
# Epoch 3 Batch 100 Loss 0.5350
# Epoch 3 Batch 200 Loss 0.3651
# Epoch 3 Batch 300 Loss 0.3482
# Epoch 3 Batch 400 Loss 0.4440
# Epoch 3 Batch 500 Loss 0.5043
# Epoch 3 Batch 600 Loss 0.3995
# Epoch 3 Batch 700 Loss 0.3580
# Epoch 3 Batch 800 Loss 0.4432
# Epoch 3 Batch 900 Loss 0.3635
# Epoch 3 Batch 1000 Loss 0.3420
# Epoch 3 Batch 1100 Loss 0.3532
# Epoch 3 Batch 1200 Loss 0.3565
# Epoch 3 Loss 0.4217
# Time taken for 1 epoch 110.04083609580994 sec
#
# Epoch 4 Batch 0 Loss 0.2689
# Epoch 4 Batch 100 Loss 0.2270
# Epoch 4 Batch 200 Loss 0.2505
# Epoch 4 Batch 300 Loss 0.2576
# Epoch 4 Batch 400 Loss 0.1861
# Epoch 4 Batch 500 Loss 0.2484
# Epoch 4 Batch 600 Loss 0.2707
# Epoch 4 Batch 700 Loss 0.1821
# Epoch 4 Batch 800 Loss 0.2602
# Epoch 4 Batch 900 Loss 0.2412
# Epoch 4 Batch 1000 Loss 0.2914
# Epoch 4 Batch 1100 Loss 0.2210
# Epoch 4 Batch 1200 Loss 0.2055
# Epoch 4 Loss 0.2502
# Time taken for 1 epoch 111.62209010124207 sec
#
# Epoch 5 Batch 0 Loss 0.1760
# Epoch 5 Batch 100 Loss 0.1696
# Epoch 5 Batch 200 Loss 0.1538
# Epoch 5 Batch 300 Loss 0.1389
# Epoch 5 Batch 400 Loss 0.2267
# Epoch 5 Batch 500 Loss 0.1285
# Epoch 5 Batch 600 Loss 0.2235
# Epoch 5 Batch 700 Loss 0.1768
# Epoch 5 Batch 800 Loss 0.1346
# Epoch 5 Batch 900 Loss 0.2070
# Epoch 5 Batch 1000 Loss 0.1787
# Epoch 5 Batch 1100 Loss 0.1734
# Epoch 5 Batch 1200 Loss 0.1841
# Epoch 5 Loss 0.1709
# Time taken for 1 epoch 110.14670085906982 sec
#
# Epoch 6 Batch 0 Loss 0.1197
# Epoch 6 Batch 100 Loss 0.0775
# Epoch 6 Batch 200 Loss 0.1324
# Epoch 6 Batch 300 Loss 0.1278
# Epoch 6 Batch 400 Loss 0.1182
# Epoch 6 Batch 500 Loss 0.1005
# Epoch 6 Batch 600 Loss 0.1346
# Epoch 6 Batch 700 Loss 0.1251
# Epoch 6 Batch 800 Loss 0.1465
# Epoch 6 Batch 900 Loss 0.1074
# Epoch 6 Batch 1000 Loss 0.1263
# Epoch 6 Batch 1100 Loss 0.1252
# Epoch 6 Batch 1200 Loss 0.1033
# Epoch 6 Loss 0.1305
# Time taken for 1 epoch 111.7387912273407 sec
#
# Epoch 7 Batch 0 Loss 0.0684
# Epoch 7 Batch 100 Loss 0.0663
# Epoch 7 Batch 200 Loss 0.1013
# Epoch 7 Batch 300 Loss 0.1178
# Epoch 7 Batch 400 Loss 0.1161
# Epoch 7 Batch 500 Loss 0.0977
# Epoch 7 Batch 600 Loss 0.0848
# Epoch 7 Batch 700 Loss 0.1094
# Epoch 7 Batch 800 Loss 0.1116
# Epoch 7 Batch 900 Loss 0.1513
# Epoch 7 Batch 1000 Loss 0.1080
# Epoch 7 Batch 1100 Loss 0.1082
# Epoch 7 Batch 1200 Loss 0.0875
# Epoch 7 Loss 0.1083
# Time taken for 1 epoch 110.15872955322266 sec
#
# Epoch 8 Batch 0 Loss 0.0833
# Epoch 8 Batch 100 Loss 0.0516
# Epoch 8 Batch 200 Loss 0.0492
# Epoch 8 Batch 300 Loss 0.0573
# Epoch 8 Batch 400 Loss 0.0839
# Epoch 8 Batch 500 Loss 0.0758
# Epoch 8 Batch 600 Loss 0.0982
# Epoch 8 Batch 700 Loss 0.1038
# Epoch 8 Batch 800 Loss 0.1426
# Epoch 8 Batch 900 Loss 0.1056
# Epoch 8 Batch 1000 Loss 0.1385
# Epoch 8 Batch 1100 Loss 0.1305
# Epoch 8 Batch 1200 Loss 0.0933
# Epoch 8 Loss 0.0946
# Time taken for 1 epoch 111.64628171920776 sec
#
# Epoch 9 Batch 0 Loss 0.0859
# Epoch 9 Batch 100 Loss 0.0858
# Epoch 9 Batch 200 Loss 0.0676
# Epoch 9 Batch 300 Loss 0.0741
# Epoch 9 Batch 400 Loss 0.0539
# Epoch 9 Batch 500 Loss 0.0735
# Epoch 9 Batch 600 Loss 0.0918
# Epoch 9 Batch 700 Loss 0.0810
# Epoch 9 Batch 800 Loss 0.0825
# Epoch 9 Batch 900 Loss 0.0604
# Epoch 9 Batch 1000 Loss 0.0950
# Epoch 9 Batch 1100 Loss 0.0900
# Epoch 9 Batch 1200 Loss 0.1082
# Epoch 9 Loss 0.0863
# Time taken for 1 epoch 110.09091281890869 sec
#
# Epoch 10 Batch 0 Loss 0.0645
# Epoch 10 Batch 100 Loss 0.0735
# Epoch 10 Batch 200 Loss 0.0741
# Epoch 10 Batch 300 Loss 0.0724
# Epoch 10 Batch 400 Loss 0.0741
# Epoch 10 Batch 500 Loss 0.0713
# Epoch 10 Batch 600 Loss 0.0838
# Epoch 10 Batch 700 Loss 0.0652
# Epoch 10 Batch 800 Loss 0.1035
# Epoch 10 Batch 900 Loss 0.0686
# Epoch 10 Batch 1000 Loss 0.0664
# Epoch 10 Batch 1100 Loss 0.1261
# Epoch 10 Batch 1200 Loss 0.0905
# Epoch 10 Loss 0.0794
# Time taken for 1 epoch 111.60652661323547 sec
#
# Epoch 11 Batch 0 Loss 0.0648
# Epoch 11 Batch 100 Loss 0.0676
# Epoch 11 Batch 200 Loss 0.0853
# Epoch 11 Batch 300 Loss 0.0721
# Epoch 11 Batch 400 Loss 0.0837
# Epoch 11 Batch 500 Loss 0.0885
# Epoch 11 Batch 600 Loss 0.0619
# Epoch 11 Batch 700 Loss 0.0658
# Epoch 11 Batch 800 Loss 0.0584
# Epoch 11 Batch 900 Loss 0.1027
# Epoch 11 Batch 1000 Loss 0.0778
# Epoch 11 Batch 1100 Loss 0.0647
# Epoch 11 Batch 1200 Loss 0.0604
# Epoch 11 Loss 0.0754
# Time taken for 1 epoch 110.02356624603271 sec
#
# Epoch 12 Batch 0 Loss 0.0780
# Epoch 12 Batch 100 Loss 0.0533
# Epoch 12 Batch 200 Loss 0.0401
# Epoch 12 Batch 300 Loss 0.0658
# Epoch 12 Batch 400 Loss 0.0616
# Epoch 12 Batch 500 Loss 0.0659
# Epoch 12 Batch 600 Loss 0.0807
# Epoch 12 Batch 700 Loss 0.0897
# Epoch 12 Batch 800 Loss 0.0970
# Epoch 12 Batch 900 Loss 0.0622
# Epoch 12 Batch 1000 Loss 0.0761
# Epoch 12 Batch 1100 Loss 0.0688
# Epoch 12 Batch 1200 Loss 0.0592
# Epoch 12 Loss 0.0716
# Time taken for 1 epoch 111.52822351455688 sec
#
# Epoch 13 Batch 0 Loss 0.0970
# Epoch 13 Batch 100 Loss 0.0591
# Epoch 13 Batch 200 Loss 0.0565
# Epoch 13 Batch 300 Loss 0.0695
# Epoch 13 Batch 400 Loss 0.0411
# Epoch 13 Batch 500 Loss 0.0574
# Epoch 13 Batch 600 Loss 0.1010
# Epoch 13 Batch 700 Loss 0.0963
# Epoch 13 Batch 800 Loss 0.0581
# Epoch 13 Batch 900 Loss 0.0593
# Epoch 13 Batch 1000 Loss 0.0568
# Epoch 13 Batch 1100 Loss 0.0857
# Epoch 13 Batch 1200 Loss 0.0815
# Epoch 13 Loss 0.0688
# Time taken for 1 epoch 110.01371002197266 sec
#
# Epoch 14 Batch 0 Loss 0.0688
# Epoch 14 Batch 100 Loss 0.0470
# Epoch 14 Batch 200 Loss 0.0694
# Epoch 14 Batch 300 Loss 0.0320
# Epoch 14 Batch 400 Loss 0.0378
# Epoch 14 Batch 500 Loss 0.1103
# Epoch 14 Batch 600 Loss 0.0529
# Epoch 14 Batch 700 Loss 0.0554
# Epoch 14 Batch 800 Loss 0.0975
# Epoch 14 Batch 900 Loss 0.0812
# Epoch 14 Batch 1000 Loss 0.0806
# Epoch 14 Batch 1100 Loss 0.0783
# Epoch 14 Batch 1200 Loss 0.0623
# Epoch 14 Loss 0.0672
# Time taken for 1 epoch 111.6142680644989 sec
#
# Epoch 15 Batch 0 Loss 0.0349
# Epoch 15 Batch 100 Loss 0.0838
# Epoch 15 Batch 200 Loss 0.0419
# Epoch 15 Batch 300 Loss 0.0354
# Epoch 15 Batch 400 Loss 0.0534
# Epoch 15 Batch 500 Loss 0.0286
# Epoch 15 Batch 600 Loss 0.0588
# Epoch 15 Batch 700 Loss 0.0407
# Epoch 15 Batch 800 Loss 0.0346
# Epoch 15 Batch 900 Loss 0.0622
# Epoch 15 Batch 1000 Loss 0.0833
# Epoch 15 Batch 1100 Loss 0.0855
# Epoch 15 Batch 1200 Loss 0.0669
# Epoch 15 Loss 0.0648
# Time taken for 1 epoch 109.9369170665741 sec
#
# Epoch 16 Batch 0 Loss 0.0564
# Epoch 16 Batch 100 Loss 0.0501
# Epoch 16 Batch 200 Loss 0.0770
# Epoch 16 Batch 300 Loss 0.0536
# Epoch 16 Batch 400 Loss 0.0565
# Epoch 16 Batch 500 Loss 0.0612
# Epoch 16 Batch 600 Loss 0.0501
# Epoch 16 Batch 700 Loss 0.0795
# Epoch 16 Batch 800 Loss 0.0389
# Epoch 16 Batch 900 Loss 0.0309
# Epoch 16 Batch 1000 Loss 0.0487
# Epoch 16 Batch 1100 Loss 0.0687
# Epoch 16 Batch 1200 Loss 0.0808
# Epoch 16 Loss 0.0629
# Time taken for 1 epoch 111.49298143386841 sec
#
# Epoch 17 Batch 0 Loss 0.0574
# Epoch 17 Batch 100 Loss 0.0872
# Epoch 17 Batch 200 Loss 0.0639
# Epoch 17 Batch 300 Loss 0.0715
# Epoch 17 Batch 400 Loss 0.0619
# Epoch 17 Batch 500 Loss 0.0433
# Epoch 17 Batch 600 Loss 0.0518
# Epoch 17 Batch 700 Loss 0.0914
# Epoch 17 Batch 800 Loss 0.0906
# Epoch 17 Batch 900 Loss 0.1048
# Epoch 17 Batch 1000 Loss 0.0642
# Epoch 17 Batch 1100 Loss 0.0409
# Epoch 17 Batch 1200 Loss 0.1055
# Epoch 17 Loss 0.0618
# Time taken for 1 epoch 110.07530403137207 sec
#
# Epoch 18 Batch 0 Loss 0.0394
# Epoch 18 Batch 100 Loss 0.0638
# Epoch 18 Batch 200 Loss 0.0683
# Epoch 18 Batch 300 Loss 0.0507
# Epoch 18 Batch 400 Loss 0.0649
# Epoch 18 Batch 500 Loss 0.0405
# Epoch 18 Batch 600 Loss 0.0652
# Epoch 18 Batch 700 Loss 0.0954
# Epoch 18 Batch 800 Loss 0.0358
# Epoch 18 Batch 900 Loss 0.0494
# Epoch 18 Batch 1000 Loss 0.0724
# Epoch 18 Batch 1100 Loss 0.0516
# Epoch 18 Batch 1200 Loss 0.0897
# Epoch 18 Loss 0.0607
# Time taken for 1 epoch 111.52401375770569 sec
#
# Epoch 19 Batch 0 Loss 0.0497
# Epoch 19 Batch 100 Loss 0.0477
# Epoch 19 Batch 200 Loss 0.0518
# Epoch 19 Batch 300 Loss 0.0575
# Epoch 19 Batch 400 Loss 0.0607
# Epoch 19 Batch 500 Loss 0.0559
# Epoch 19 Batch 600 Loss 0.0499
# Epoch 19 Batch 700 Loss 0.0876
# Epoch 19 Batch 800 Loss 0.0689
# Epoch 19 Batch 900 Loss 0.0510
# Epoch 19 Batch 1000 Loss 0.0511
# Epoch 19 Batch 1100 Loss 0.0902
# Epoch 19 Batch 1200 Loss 0.0766
# Epoch 19 Loss 0.0591
# Time taken for 1 epoch 110.03549027442932 sec
#
# Epoch 20 Batch 0 Loss 0.0438
# Epoch 20 Batch 100 Loss 0.0455
# Epoch 20 Batch 200 Loss 0.0524
# Epoch 20 Batch 300 Loss 0.0685
# Epoch 20 Batch 400 Loss 0.0536
# Epoch 20 Batch 500 Loss 0.0318
# Epoch 20 Batch 600 Loss 0.0695
# Epoch 20 Batch 700 Loss 0.0650
# Epoch 20 Batch 800 Loss 0.0838
# Epoch 20 Batch 900 Loss 0.0644
# Epoch 20 Batch 1000 Loss 0.0520
# Epoch 20 Batch 1100 Loss 0.0659
# Epoch 20 Batch 1200 Loss 0.0836
# Epoch 20 Loss 0.0582
# Time taken for 1 epoch 111.56095671653748 sec
#
# Epoch 21 Batch 0 Loss 0.0561
# Epoch 21 Batch 100 Loss 0.0411
# Epoch 21 Batch 200 Loss 0.0506
# Epoch 21 Batch 300 Loss 0.0593
# Epoch 21 Batch 400 Loss 0.0750
# Epoch 21 Batch 500 Loss 0.0640
# Epoch 21 Batch 600 Loss 0.0422
# Epoch 21 Batch 700 Loss 0.0575
# Epoch 21 Batch 800 Loss 0.0871
# Epoch 21 Batch 900 Loss 0.0283
# Epoch 21 Batch 1000 Loss 0.0395
# Epoch 21 Batch 1100 Loss 0.0886
# Epoch 21 Batch 1200 Loss 0.0740
# Epoch 21 Loss 0.0572
# Time taken for 1 epoch 110.08198857307434 sec
#
# Epoch 22 Batch 0 Loss 0.0620
# Epoch 22 Batch 100 Loss 0.0536
# Epoch 22 Batch 200 Loss 0.0452
# Epoch 22 Batch 300 Loss 0.0371
# Epoch 22 Batch 400 Loss 0.0792
# Epoch 22 Batch 500 Loss 0.0676
# Epoch 22 Batch 600 Loss 0.0371
# Epoch 22 Batch 700 Loss 0.0435
# Epoch 22 Batch 800 Loss 0.0331
# Epoch 22 Batch 900 Loss 0.0608
# Epoch 22 Batch 1000 Loss 0.0635
# Epoch 22 Batch 1100 Loss 0.0863
# Epoch 22 Batch 1200 Loss 0.0594
# Epoch 22 Loss 0.0569
# Time taken for 1 epoch 111.63392448425293 sec
#
# Epoch 23 Batch 0 Loss 0.0447
# Epoch 23 Batch 100 Loss 0.0643
# Epoch 23 Batch 200 Loss 0.0363
# Epoch 23 Batch 300 Loss 0.0473
# Epoch 23 Batch 400 Loss 0.0628
# Epoch 23 Batch 500 Loss 0.0386
# Epoch 23 Batch 600 Loss 0.0366
# Epoch 23 Batch 700 Loss 0.0558
# Epoch 23 Batch 800 Loss 0.0352
# Epoch 23 Batch 900 Loss 0.0681
# Epoch 23 Batch 1000 Loss 0.0762
# Epoch 23 Batch 1100 Loss 0.0849
# Epoch 23 Batch 1200 Loss 0.0796
# Epoch 23 Loss 0.0555
# Time taken for 1 epoch 109.98640990257263 sec
#
# Epoch 24 Batch 0 Loss 0.0453
# Epoch 24 Batch 100 Loss 0.0361
# Epoch 24 Batch 200 Loss 0.0463
# Epoch 24 Batch 300 Loss 0.0484
# Epoch 24 Batch 400 Loss 0.0636
# Epoch 24 Batch 500 Loss 0.0267
# Epoch 24 Batch 600 Loss 0.0409
# Epoch 24 Batch 700 Loss 0.0296
# Epoch 24 Batch 800 Loss 0.0593
# Epoch 24 Batch 900 Loss 0.0392
# Epoch 24 Batch 1000 Loss 0.0463
# Epoch 24 Batch 1100 Loss 0.0528
# Epoch 24 Batch 1200 Loss 0.0712
# Epoch 24 Loss 0.0555
# Time taken for 1 epoch 111.49274444580078 sec
#
# Epoch 25 Batch 0 Loss 0.0457
# Epoch 25 Batch 100 Loss 0.0300
# Epoch 25 Batch 200 Loss 0.0215
# Epoch 25 Batch 300 Loss 0.0837
# Epoch 25 Batch 400 Loss 0.0334
# Epoch 25 Batch 500 Loss 0.0656
# Epoch 25 Batch 600 Loss 0.0495
# Epoch 25 Batch 700 Loss 0.0499
# Epoch 25 Batch 800 Loss 0.0433
# Epoch 25 Batch 900 Loss 0.0798
# Epoch 25 Batch 1000 Loss 0.0849
# Epoch 25 Batch 1100 Loss 0.0629
# Epoch 25 Batch 1200 Loss 0.0573
# Epoch 25 Loss 0.0547
# Time taken for 1 epoch 110.00572371482849 sec
#
# Epoch 26 Batch 0 Loss 0.0315
# Epoch 26 Batch 100 Loss 0.0504
# Epoch 26 Batch 200 Loss 0.0617
# Epoch 26 Batch 300 Loss 0.0446
# Epoch 26 Batch 400 Loss 0.0681
# Epoch 26 Batch 500 Loss 0.0569
# Epoch 26 Batch 600 Loss 0.0447
# Epoch 26 Batch 700 Loss 0.0633
# Epoch 26 Batch 800 Loss 0.0442
# Epoch 26 Batch 900 Loss 0.0353
# Epoch 26 Batch 1000 Loss 0.0765
# Epoch 26 Batch 1100 Loss 0.1023
# Epoch 26 Batch 1200 Loss 0.0803
# Epoch 26 Loss 0.0537
# Time taken for 1 epoch 111.35143947601318 sec
#
# Epoch 27 Batch 0 Loss 0.0594
# Epoch 27 Batch 100 Loss 0.0513
# Epoch 27 Batch 200 Loss 0.0295
# Epoch 27 Batch 300 Loss 0.0548
# Epoch 27 Batch 400 Loss 0.0315
# Epoch 27 Batch 500 Loss 0.0381
# Epoch 27 Batch 600 Loss 0.0443
# Epoch 27 Batch 700 Loss 0.0642
# Epoch 27 Batch 800 Loss 0.0465
# Epoch 27 Batch 900 Loss 0.0587
# Epoch 27 Batch 1000 Loss 0.0520
# Epoch 27 Batch 1100 Loss 0.0880
# Epoch 27 Batch 1200 Loss 0.0530
# Epoch 27 Loss 0.0524
# Time taken for 1 epoch 109.89163613319397 sec
#
# Epoch 28 Batch 0 Loss 0.0420
# Epoch 28 Batch 100 Loss 0.0439
# Epoch 28 Batch 200 Loss 0.0762
# Epoch 28 Batch 300 Loss 0.0381
# Epoch 28 Batch 400 Loss 0.0561
# Epoch 28 Batch 500 Loss 0.0723
# Epoch 28 Batch 600 Loss 0.0648
# Epoch 28 Batch 700 Loss 0.0672
# Epoch 28 Batch 800 Loss 0.0403
# Epoch 28 Batch 900 Loss 0.0483
# Epoch 28 Batch 1000 Loss 0.0331
# Epoch 28 Batch 1100 Loss 0.0537
# Epoch 28 Batch 1200 Loss 0.0753
# Epoch 28 Loss 0.0522
# Time taken for 1 epoch 111.4210889339447 sec
#
# Epoch 29 Batch 0 Loss 0.0619
# Epoch 29 Batch 100 Loss 0.0239
# Epoch 29 Batch 200 Loss 0.0447
# Epoch 29 Batch 300 Loss 0.0321
# Epoch 29 Batch 400 Loss 0.0166
# Epoch 29 Batch 500 Loss 0.0395
# Epoch 29 Batch 600 Loss 0.0411
# Epoch 29 Batch 700 Loss 0.0531
# Epoch 29 Batch 800 Loss 0.0593
# Epoch 29 Batch 900 Loss 0.0560
# Epoch 29 Batch 1000 Loss 0.0796
# Epoch 29 Batch 1100 Loss 0.0392
# Epoch 29 Batch 1200 Loss 0.0695
# Epoch 29 Loss 0.0511
# Time taken for 1 epoch 109.86177706718445 sec
#
# Epoch 30 Batch 0 Loss 0.0726
# Epoch 30 Batch 100 Loss 0.0278
# Epoch 30 Batch 200 Loss 0.0435
# Epoch 30 Batch 300 Loss 0.0427
# Epoch 30 Batch 400 Loss 0.0319
# Epoch 30 Batch 500 Loss 0.0533
# Epoch 30 Batch 600 Loss 0.0427
# Epoch 30 Batch 700 Loss 0.0459
# Epoch 30 Batch 800 Loss 0.0403
# Epoch 30 Batch 900 Loss 0.0309
# Epoch 30 Batch 1000 Loss 0.0468
# Epoch 30 Batch 1100 Loss 0.0716
# Epoch 30 Batch 1200 Loss 0.0522
# Epoch 30 Loss 0.0511
# Time taken for 1 epoch 111.38119149208069 sec
#
# Epoch 31 Batch 0 Loss 0.0360
# Epoch 31 Batch 100 Loss 0.0459
# Epoch 31 Batch 200 Loss 0.0288
# Epoch 31 Batch 300 Loss 0.0481
# Epoch 31 Batch 400 Loss 0.0186
# Epoch 31 Batch 500 Loss 0.0323
# Epoch 31 Batch 600 Loss 0.0318
# Epoch 31 Batch 700 Loss 0.0493
# Epoch 31 Batch 800 Loss 0.0866
# Epoch 31 Batch 900 Loss 0.1426
# Epoch 31 Batch 1000 Loss 0.0592
# Epoch 31 Batch 1100 Loss 0.0723
# Epoch 31 Batch 1200 Loss 0.0389
# Epoch 31 Loss 0.0502
# Time taken for 1 epoch 109.80044507980347 sec
#
# Epoch 32 Batch 0 Loss 0.0502
# Epoch 32 Batch 100 Loss 0.0279
# Epoch 32 Batch 200 Loss 0.0489
# Epoch 32 Batch 300 Loss 0.0623
# Epoch 32 Batch 400 Loss 0.0585
# Epoch 32 Batch 500 Loss 0.0321
# Epoch 32 Batch 600 Loss 0.0432
# Epoch 32 Batch 700 Loss 0.0625
# Epoch 32 Batch 800 Loss 0.0698
# Epoch 32 Batch 900 Loss 0.0732
# Epoch 32 Batch 1000 Loss 0.0943
# Epoch 32 Batch 1100 Loss 0.0387
# Epoch 32 Batch 1200 Loss 0.0908
# Epoch 32 Loss 0.0499
# Time taken for 1 epoch 111.28813934326172 sec
#
# Epoch 33 Batch 0 Loss 0.0326
# Epoch 33 Batch 100 Loss 0.0654
# Epoch 33 Batch 200 Loss 0.0410
# Epoch 33 Batch 300 Loss 0.0369
# Epoch 33 Batch 400 Loss 0.0560
# Epoch 33 Batch 500 Loss 0.0485
# Epoch 33 Batch 600 Loss 0.0390
# Epoch 33 Batch 700 Loss 0.0468
# Epoch 33 Batch 800 Loss 0.0536
# Epoch 33 Batch 900 Loss 0.0448
# Epoch 33 Batch 1000 Loss 0.0451
# Epoch 33 Batch 1100 Loss 0.0747
# Epoch 33 Batch 1200 Loss 0.0400
# Epoch 33 Loss 0.0491
# Time taken for 1 epoch 109.83564257621765 sec
#
# Epoch 34 Batch 0 Loss 0.0352
# Epoch 34 Batch 100 Loss 0.0267
# Epoch 34 Batch 200 Loss 0.0313
# Epoch 34 Batch 300 Loss 0.0443
# Epoch 34 Batch 400 Loss 0.0114
# Epoch 34 Batch 500 Loss 0.0332
# Epoch 34 Batch 600 Loss 0.0745
# Epoch 34 Batch 700 Loss 0.0572
# Epoch 34 Batch 800 Loss 0.0404
# Epoch 34 Batch 900 Loss 0.0327
# Epoch 34 Batch 1000 Loss 0.0478
# Epoch 34 Batch 1100 Loss 0.0395
# Epoch 34 Batch 1200 Loss 0.0637
# Epoch 34 Loss 0.0486
# Time taken for 1 epoch 111.26193952560425 sec
#
# Epoch 35 Batch 0 Loss 0.0440
# Epoch 35 Batch 100 Loss 0.0480
# Epoch 35 Batch 200 Loss 0.0256
# Epoch 35 Batch 300 Loss 0.0296
# Epoch 35 Batch 400 Loss 0.0147
# Epoch 35 Batch 500 Loss 0.0571
# Epoch 35 Batch 600 Loss 0.0486
# Epoch 35 Batch 700 Loss 0.0252
# Epoch 35 Batch 800 Loss 0.0564
# Epoch 35 Batch 900 Loss 0.0398
# Epoch 35 Batch 1000 Loss 0.0447
# Epoch 35 Batch 1100 Loss 0.0710
# Epoch 35 Batch 1200 Loss 0.0504
# Epoch 35 Loss 0.0475
# Time taken for 1 epoch 109.71547484397888 sec
#
# Epoch 36 Batch 0 Loss 0.0448
# Epoch 36 Batch 100 Loss 0.0246
# Epoch 36 Batch 200 Loss 0.0586
# Epoch 36 Batch 300 Loss 0.0327
# Epoch 36 Batch 400 Loss 0.0627
# Epoch 36 Batch 500 Loss 0.0486
# Epoch 36 Batch 600 Loss 0.0371
# Epoch 36 Batch 700 Loss 0.0315
# Epoch 36 Batch 800 Loss 0.0588
# Epoch 36 Batch 900 Loss 0.0472
# Epoch 36 Batch 1000 Loss 0.0838
# Epoch 36 Batch 1100 Loss 0.1057
# Epoch 36 Batch 1200 Loss 0.0614
# Epoch 36 Loss 0.0477
# Time taken for 1 epoch 111.23575973510742 sec
#
# Epoch 37 Batch 0 Loss 0.0211
# Epoch 37 Batch 100 Loss 0.0169
# Epoch 37 Batch 200 Loss 0.0209
# Epoch 37 Batch 300 Loss 0.0354
# Epoch 37 Batch 400 Loss 0.0362
# Epoch 37 Batch 500 Loss 0.0614
# Epoch 37 Batch 600 Loss 0.0533
# Epoch 37 Batch 700 Loss 0.0540
# Epoch 37 Batch 800 Loss 0.0498
# Epoch 37 Batch 900 Loss 0.0552
# Epoch 37 Batch 1000 Loss 0.0357
# Epoch 37 Batch 1100 Loss 0.0864
# Epoch 37 Batch 1200 Loss 0.0436
# Epoch 37 Loss 0.0469
# Time taken for 1 epoch 109.69994735717773 sec
#
# Epoch 38 Batch 0 Loss 0.0265
# Epoch 38 Batch 100 Loss 0.0186
# Epoch 38 Batch 200 Loss 0.0483
# Epoch 38 Batch 300 Loss 0.0265
# Epoch 38 Batch 400 Loss 0.0545
# Epoch 38 Batch 500 Loss 0.0275
# Epoch 38 Batch 600 Loss 0.0351
# Epoch 38 Batch 700 Loss 0.0583
# Epoch 38 Batch 800 Loss 0.0616
# Epoch 38 Batch 900 Loss 0.0635
# Epoch 38 Batch 1000 Loss 0.0669
# Epoch 38 Batch 1100 Loss 0.0525
# Epoch 38 Batch 1200 Loss 0.0481
# Epoch 38 Loss 0.0463
# Time taken for 1 epoch 111.28385996818542 sec
#
# Epoch 39 Batch 0 Loss 0.0328
# Epoch 39 Batch 100 Loss 0.0664
# Epoch 39 Batch 200 Loss 0.0342
# Epoch 39 Batch 300 Loss 0.0339
# Epoch 39 Batch 400 Loss 0.0295
# Epoch 39 Batch 500 Loss 0.0412
# Epoch 39 Batch 600 Loss 0.0542
# Epoch 39 Batch 700 Loss 0.0563
# Epoch 39 Batch 800 Loss 0.0234
# Epoch 39 Batch 900 Loss 0.0567
# Epoch 39 Batch 1000 Loss 0.0526
# Epoch 39 Batch 1100 Loss 0.0527
# Epoch 39 Batch 1200 Loss 0.0499
# Epoch 39 Loss 0.0460
# Time taken for 1 epoch 109.72950053215027 sec
#
# Epoch 40 Batch 0 Loss 0.0483
# Epoch 40 Batch 100 Loss 0.0440
# Epoch 40 Batch 200 Loss 0.0488
# Epoch 40 Batch 300 Loss 0.0322
# Epoch 40 Batch 400 Loss 0.0352
# Epoch 40 Batch 500 Loss 0.0536
# Epoch 40 Batch 600 Loss 0.0309
# Epoch 40 Batch 700 Loss 0.0380
# Epoch 40 Batch 800 Loss 0.0567
# Epoch 40 Batch 900 Loss 0.0633
# Epoch 40 Batch 1000 Loss 0.0437
# Epoch 40 Batch 1100 Loss 0.0206
# Epoch 40 Batch 1200 Loss 0.0519
# Epoch 40 Loss 0.0461
# Time taken for 1 epoch 111.11401605606079 sec
#
# Epoch 41 Batch 0 Loss 0.0221
# Epoch 41 Batch 100 Loss 0.0394
# Epoch 41 Batch 200 Loss 0.0354
# Epoch 41 Batch 300 Loss 0.0514
# Epoch 41 Batch 400 Loss 0.0597
# Epoch 41 Batch 500 Loss 0.0678
# Epoch 41 Batch 600 Loss 0.0471
# Epoch 41 Batch 700 Loss 0.0673
# Epoch 41 Batch 800 Loss 0.0545
# Epoch 41 Batch 900 Loss 0.0820
# Epoch 41 Batch 1000 Loss 0.0569
# Epoch 41 Batch 1100 Loss 0.0636
# Epoch 41 Batch 1200 Loss 0.0400
# Epoch 41 Loss 0.0454
# Time taken for 1 epoch 109.76284432411194 sec
#
# Epoch 42 Batch 0 Loss 0.0176
# Epoch 42 Batch 100 Loss 0.0386
# Epoch 42 Batch 200 Loss 0.0521
# Epoch 42 Batch 300 Loss 0.0322
# Epoch 42 Batch 400 Loss 0.0364
# Epoch 42 Batch 500 Loss 0.0484
# Epoch 42 Batch 600 Loss 0.0224
# Epoch 42 Batch 700 Loss 0.0325
# Epoch 42 Batch 800 Loss 0.0793
# Epoch 42 Batch 900 Loss 0.0641
# Epoch 42 Batch 1000 Loss 0.0476
# Epoch 42 Batch 1100 Loss 0.0828
# Epoch 42 Batch 1200 Loss 0.0504
# Epoch 42 Loss 0.0447
# Time taken for 1 epoch 111.12973308563232 sec
#
# Epoch 43 Batch 0 Loss 0.0266
# Epoch 43 Batch 100 Loss 0.0548
# Epoch 43 Batch 200 Loss 0.0241
# Epoch 43 Batch 300 Loss 0.0497
# Epoch 43 Batch 400 Loss 0.0483
# Epoch 43 Batch 500 Loss 0.0446
# Epoch 43 Batch 600 Loss 0.0472
# Epoch 43 Batch 700 Loss 0.0597
# Epoch 43 Batch 800 Loss 0.0523
# Epoch 43 Batch 900 Loss 0.0758
# Epoch 43 Batch 1000 Loss 0.0534
# Epoch 43 Batch 1100 Loss 0.0533
# Epoch 43 Batch 1200 Loss 0.0380
# Epoch 43 Loss 0.0443
# Time taken for 1 epoch 109.68347644805908 sec
#
# Epoch 44 Batch 0 Loss 0.0291
# Epoch 44 Batch 100 Loss 0.0315
# Epoch 44 Batch 200 Loss 0.0426
# Epoch 44 Batch 300 Loss 0.0218
# Epoch 44 Batch 400 Loss 0.0437
# Epoch 44 Batch 500 Loss 0.0185
# Epoch 44 Batch 600 Loss 0.0393
# Epoch 44 Batch 700 Loss 0.0292
# Epoch 44 Batch 800 Loss 0.0502
# Epoch 44 Batch 900 Loss 0.0444
# Epoch 44 Batch 1000 Loss 0.0377
# Epoch 44 Batch 1100 Loss 0.0254
# Epoch 44 Batch 1200 Loss 0.0508
# Epoch 44 Loss 0.0437
# Time taken for 1 epoch 111.21098065376282 sec
#
# Epoch 45 Batch 0 Loss 0.0387
# Epoch 45 Batch 100 Loss 0.0210
# Epoch 45 Batch 200 Loss 0.0432
# Epoch 45 Batch 300 Loss 0.0408
# Epoch 45 Batch 400 Loss 0.0237
# Epoch 45 Batch 500 Loss 0.0384
# Epoch 45 Batch 600 Loss 0.0437
# Epoch 45 Batch 700 Loss 0.0542
# Epoch 45 Batch 800 Loss 0.0449
# Epoch 45 Batch 900 Loss 0.0488
# Epoch 45 Batch 1000 Loss 0.0446
# Epoch 45 Batch 1100 Loss 0.0373
# Epoch 45 Batch 1200 Loss 0.0674
# Epoch 45 Loss 0.0441
# Time taken for 1 epoch 109.64792013168335 sec
#
# Epoch 46 Batch 0 Loss 0.0297
# Epoch 46 Batch 100 Loss 0.0890
# Epoch 46 Batch 200 Loss 0.0326
# Epoch 46 Batch 300 Loss 0.0625
# Epoch 46 Batch 400 Loss 0.0464
# Epoch 46 Batch 500 Loss 0.0420
# Epoch 46 Batch 600 Loss 0.0305
# Epoch 46 Batch 700 Loss 0.0360
# Epoch 46 Batch 800 Loss 0.0570
# Epoch 46 Batch 900 Loss 0.0339
# Epoch 46 Batch 1000 Loss 0.0350
# Epoch 46 Batch 1100 Loss 0.0654
# Epoch 46 Batch 1200 Loss 0.0508
# Epoch 46 Loss 0.0428
# Time taken for 1 epoch 111.28085136413574 sec
#
# Epoch 47 Batch 0 Loss 0.0285
# Epoch 47 Batch 100 Loss 0.0189
# Epoch 47 Batch 200 Loss 0.0348
# Epoch 47 Batch 300 Loss 0.0386
# Epoch 47 Batch 400 Loss 0.0550
# Epoch 47 Batch 500 Loss 0.0397
# Epoch 47 Batch 600 Loss 0.0440
# Epoch 47 Batch 700 Loss 0.0547
# Epoch 47 Batch 800 Loss 0.0494
# Epoch 47 Batch 900 Loss 0.0293
# Epoch 47 Batch 1000 Loss 0.0456
# Epoch 47 Batch 1100 Loss 0.0313
# Epoch 47 Batch 1200 Loss 0.0294
# Epoch 47 Loss 0.0428
# Time taken for 1 epoch 109.56829285621643 sec
#
# Epoch 48 Batch 0 Loss 0.0237
# Epoch 48 Batch 100 Loss 0.0288
# Epoch 48 Batch 200 Loss 0.0353
# Epoch 48 Batch 300 Loss 0.0709
# Epoch 48 Batch 400 Loss 0.0338
# Epoch 48 Batch 500 Loss 0.0550
# Epoch 48 Batch 600 Loss 0.0262
# Epoch 48 Batch 700 Loss 0.0222
# Epoch 48 Batch 800 Loss 0.0343
# Epoch 48 Batch 900 Loss 0.0247
# Epoch 48 Batch 1000 Loss 0.0245
# Epoch 48 Batch 1100 Loss 0.0603
# Epoch 48 Batch 1200 Loss 0.0490
# Epoch 48 Loss 0.0422
# Time taken for 1 epoch 111.05364561080933 sec
#
# Epoch 49 Batch 0 Loss 0.0124
# Epoch 49 Batch 100 Loss 0.0335
# Epoch 49 Batch 200 Loss 0.0293
# Epoch 49 Batch 300 Loss 0.0489
# Epoch 49 Batch 400 Loss 0.0430
# Epoch 49 Batch 500 Loss 0.0373
# Epoch 49 Batch 600 Loss 0.0452
# Epoch 49 Batch 700 Loss 0.0369
# Epoch 49 Batch 800 Loss 0.0598
# Epoch 49 Batch 900 Loss 0.0557
# Epoch 49 Batch 1000 Loss 0.0505
# Epoch 49 Batch 1100 Loss 0.0818
# Epoch 49 Batch 1200 Loss 0.0717
# Epoch 49 Loss 0.0420
# Time taken for 1 epoch 109.70762014389038 sec
#
# Epoch 50 Batch 0 Loss 0.0345
# Epoch 50 Batch 100 Loss 0.0388
# Epoch 50 Batch 200 Loss 0.0501
# Epoch 50 Batch 300 Loss 0.0318
# Epoch 50 Batch 400 Loss 0.0287
# Epoch 50 Batch 500 Loss 0.0200
# Epoch 50 Batch 600 Loss 0.0273
# Epoch 50 Batch 700 Loss 0.0810
# Epoch 50 Batch 800 Loss 0.0538
# Epoch 50 Batch 900 Loss 0.0496
# Epoch 50 Batch 1000 Loss 0.0454
# Epoch 50 Batch 1100 Loss 0.0675
# Epoch 50 Batch 1200 Loss 0.0467
# Epoch 50 Loss 0.0419
# Time taken for 1 epoch 111.12099719047546 sec
#
# Epoch 51 Batch 0 Loss 0.0433
# Epoch 51 Batch 100 Loss 0.0281
# Epoch 51 Batch 200 Loss 0.0407
# Epoch 51 Batch 300 Loss 0.0443
# Epoch 51 Batch 400 Loss 0.0449
# Epoch 51 Batch 500 Loss 0.0466
# Epoch 51 Batch 600 Loss 0.0422
# Epoch 51 Batch 700 Loss 0.0422
# Epoch 51 Batch 800 Loss 0.0727
# Epoch 51 Batch 900 Loss 0.0463
# Epoch 51 Batch 1000 Loss 0.0519
# Epoch 51 Batch 1100 Loss 0.0592
# Epoch 51 Batch 1200 Loss 0.0321
# Epoch 51 Loss 0.0416
# Time taken for 1 epoch 109.61580014228821 sec
#
# Epoch 52 Batch 0 Loss 0.0367
# Epoch 52 Batch 100 Loss 0.0270
# Epoch 52 Batch 200 Loss 0.0382
# Epoch 52 Batch 300 Loss 0.0332
# Epoch 52 Batch 400 Loss 0.0522
# Epoch 52 Batch 500 Loss 0.0446
# Epoch 52 Batch 600 Loss 0.0509
# Epoch 52 Batch 700 Loss 0.0549
# Epoch 52 Batch 800 Loss 0.0558
# Epoch 52 Batch 900 Loss 0.0760
# Epoch 52 Batch 1000 Loss 0.0415
# Epoch 52 Batch 1100 Loss 0.0389
# Epoch 52 Batch 1200 Loss 0.0418
# Epoch 52 Loss 0.0409
# Time taken for 1 epoch 111.07015061378479 sec
#
# Epoch 53 Batch 0 Loss 0.0356
# Epoch 53 Batch 100 Loss 0.0579
# Epoch 53 Batch 200 Loss 0.0420
# Epoch 53 Batch 300 Loss 0.0309
# Epoch 53 Batch 400 Loss 0.0309
# Epoch 53 Batch 500 Loss 0.0566
# Epoch 53 Batch 600 Loss 0.0481
# Epoch 53 Batch 700 Loss 0.0590
# Epoch 53 Batch 800 Loss 0.0519
# Epoch 53 Batch 900 Loss 0.0416
# Epoch 53 Batch 1000 Loss 0.0307
# Epoch 53 Batch 1100 Loss 0.0584
# Epoch 53 Batch 1200 Loss 0.0517
# Epoch 53 Loss 0.0411
# Time taken for 1 epoch 109.60691523551941 sec
#
# Epoch 54 Batch 0 Loss 0.0285
# Epoch 54 Batch 100 Loss 0.0229
# Epoch 54 Batch 200 Loss 0.0185
# Epoch 54 Batch 300 Loss 0.0390
# Epoch 54 Batch 400 Loss 0.0415
# Epoch 54 Batch 500 Loss 0.0330
# Epoch 54 Batch 600 Loss 0.0210
# Epoch 54 Batch 700 Loss 0.0490
# Epoch 54 Batch 800 Loss 0.0294
# Epoch 54 Batch 900 Loss 0.0616
# Epoch 54 Batch 1000 Loss 0.0532
# Epoch 54 Batch 1100 Loss 0.0413
# Epoch 54 Batch 1200 Loss 0.0470
# Epoch 54 Loss 0.0410
# Time taken for 1 epoch 111.1914131641388 sec
#
# Epoch 55 Batch 0 Loss 0.0274
# Epoch 55 Batch 100 Loss 0.0185
# Epoch 55 Batch 200 Loss 0.0205
# Epoch 55 Batch 300 Loss 0.0332
# Epoch 55 Batch 400 Loss 0.0309
# Epoch 55 Batch 500 Loss 0.0660
# Epoch 55 Batch 600 Loss 0.0567
# Epoch 55 Batch 700 Loss 0.0429
# Epoch 55 Batch 800 Loss 0.0602
# Epoch 55 Batch 900 Loss 0.0651
# Epoch 55 Batch 1000 Loss 0.0526
# Epoch 55 Batch 1100 Loss 0.0652
# Epoch 55 Batch 1200 Loss 0.0694
# Epoch 55 Loss 0.0406
# Time taken for 1 epoch 109.52597784996033 sec
#
# Epoch 56 Batch 0 Loss 0.0249
# Epoch 56 Batch 100 Loss 0.0102
# Epoch 56 Batch 200 Loss 0.0513
# Epoch 56 Batch 300 Loss 0.0264
# Epoch 56 Batch 400 Loss 0.0370
# Epoch 56 Batch 500 Loss 0.0491
# Epoch 56 Batch 600 Loss 0.0476
# Epoch 56 Batch 700 Loss 0.0545
# Epoch 56 Batch 800 Loss 0.0430
# Epoch 56 Batch 900 Loss 0.0395
# Epoch 56 Batch 1000 Loss 0.0520
# Epoch 56 Batch 1100 Loss 0.0492
# Epoch 56 Batch 1200 Loss 0.0547
# Epoch 56 Loss 0.0395
# Time taken for 1 epoch 111.08364796638489 sec
#
# Epoch 57 Batch 0 Loss 0.0293
# Epoch 57 Batch 100 Loss 0.0344
# Epoch 57 Batch 200 Loss 0.0155
# Epoch 57 Batch 300 Loss 0.0346
# Epoch 57 Batch 400 Loss 0.0512
# Epoch 57 Batch 500 Loss 0.0199
# Epoch 57 Batch 600 Loss 0.0437
# Epoch 57 Batch 700 Loss 0.0621
# Epoch 57 Batch 800 Loss 0.0370
# Epoch 57 Batch 900 Loss 0.0330
# Epoch 57 Batch 1000 Loss 0.0403
# Epoch 57 Batch 1100 Loss 0.0270
# Epoch 57 Batch 1200 Loss 0.0407
# Epoch 57 Loss 0.0402
# Time taken for 1 epoch 109.71882677078247 sec
#
# Epoch 58 Batch 0 Loss 0.0124
# Epoch 58 Batch 100 Loss 0.0336
# Epoch 58 Batch 200 Loss 0.0374
# Epoch 58 Batch 300 Loss 0.0359
# Epoch 58 Batch 400 Loss 0.0269
# Epoch 58 Batch 500 Loss 0.0323
# Epoch 58 Batch 600 Loss 0.0443
# Epoch 58 Batch 700 Loss 0.0620
# Epoch 58 Batch 800 Loss 0.0588
# Epoch 58 Batch 900 Loss 0.0386
# Epoch 58 Batch 1000 Loss 0.0568
# Epoch 58 Batch 1100 Loss 0.0643
# Epoch 58 Batch 1200 Loss 0.0330
# Epoch 58 Loss 0.0393
# Time taken for 1 epoch 111.10719203948975 sec
#
# Epoch 59 Batch 0 Loss 0.0369
# Epoch 59 Batch 100 Loss 0.0288
# Epoch 59 Batch 200 Loss 0.0302
# Epoch 59 Batch 300 Loss 0.0308
# Epoch 59 Batch 400 Loss 0.0632
# Epoch 59 Batch 500 Loss 0.0416
# Epoch 59 Batch 600 Loss 0.0827
# Epoch 59 Batch 700 Loss 0.0452
# Epoch 59 Batch 800 Loss 0.0385
# Epoch 59 Batch 900 Loss 0.0682
# Epoch 59 Batch 1000 Loss 0.0401
# Epoch 59 Batch 1100 Loss 0.0412
# Epoch 59 Batch 1200 Loss 0.0433
# Epoch 59 Loss 0.0394
# Time taken for 1 epoch 109.5590546131134 sec
#
# Epoch 60 Batch 0 Loss 0.0235
# Epoch 60 Batch 100 Loss 0.0086
# Epoch 60 Batch 200 Loss 0.0308
# Epoch 60 Batch 300 Loss 0.0563
# Epoch 60 Batch 400 Loss 0.0445
# Epoch 60 Batch 500 Loss 0.0219
# Epoch 60 Batch 600 Loss 0.0222
# Epoch 60 Batch 700 Loss 0.0443
# Epoch 60 Batch 800 Loss 0.0350
# Epoch 60 Batch 900 Loss 0.0483
# Epoch 60 Batch 1000 Loss 0.0488
# Epoch 60 Batch 1100 Loss 0.0401
# Epoch 60 Batch 1200 Loss 0.0383
# Epoch 60 Loss 0.0391
# Time taken for 1 epoch 111.28630018234253 sec
#
# Epoch 61 Batch 0 Loss 0.0244
# Epoch 61 Batch 100 Loss 0.0206
# Epoch 61 Batch 200 Loss 0.0375
# Epoch 61 Batch 300 Loss 0.0371
# Epoch 61 Batch 400 Loss 0.0301
# Epoch 61 Batch 500 Loss 0.0254
# Epoch 61 Batch 600 Loss 0.0328
# Epoch 61 Batch 700 Loss 0.0484
# Epoch 61 Batch 800 Loss 0.0304
# Epoch 61 Batch 900 Loss 0.0594
# Epoch 61 Batch 1000 Loss 0.0430
# Epoch 61 Batch 1100 Loss 0.0497
# Epoch 61 Batch 1200 Loss 0.0483
# Epoch 61 Loss 0.0390
# Time taken for 1 epoch 109.73492765426636 sec
#
# Epoch 62 Batch 0 Loss 0.0531
# Epoch 62 Batch 100 Loss 0.0796
# Epoch 62 Batch 200 Loss 0.0262
# Epoch 62 Batch 300 Loss 0.0338
# Epoch 62 Batch 400 Loss 0.0196
# Epoch 62 Batch 500 Loss 0.0391
# Epoch 62 Batch 600 Loss 0.0193
# Epoch 62 Batch 700 Loss 0.0631
# Epoch 62 Batch 800 Loss 0.0298
# Epoch 62 Batch 900 Loss 0.0412
# Epoch 62 Batch 1000 Loss 0.0661
# Epoch 62 Batch 1100 Loss 0.0479
# Epoch 62 Batch 1200 Loss 0.0566
# Epoch 62 Loss 0.0399
# Time taken for 1 epoch 111.11323356628418 sec
#
# Epoch 63 Batch 0 Loss 0.0429
# Epoch 63 Batch 100 Loss 0.0328
# Epoch 63 Batch 200 Loss 0.0298
# Epoch 63 Batch 300 Loss 0.0428
# Epoch 63 Batch 400 Loss 0.0261
# Epoch 63 Batch 500 Loss 0.0515
# Epoch 63 Batch 600 Loss 0.0332
# Epoch 63 Batch 700 Loss 0.0635
# Epoch 63 Batch 800 Loss 0.0602
# Epoch 63 Batch 900 Loss 0.0324
# Epoch 63 Batch 1000 Loss 0.0163
# Epoch 63 Batch 1100 Loss 0.0350
# Epoch 63 Batch 1200 Loss 0.0454
# Epoch 63 Loss 0.0385
# Time taken for 1 epoch 109.66589593887329 sec
#
# Epoch 64 Batch 0 Loss 0.0290
# Epoch 64 Batch 100 Loss 0.0603
# Epoch 64 Batch 200 Loss 0.0284
# Epoch 64 Batch 300 Loss 0.0262
# Epoch 64 Batch 400 Loss 0.0250
# Epoch 64 Batch 500 Loss 0.0308
# Epoch 64 Batch 600 Loss 0.0436
# Epoch 64 Batch 700 Loss 0.0439
# Epoch 64 Batch 800 Loss 0.0160
# Epoch 64 Batch 900 Loss 0.0312
# Epoch 64 Batch 1000 Loss 0.0363
# Epoch 64 Batch 1100 Loss 0.0719
# Epoch 64 Batch 1200 Loss 0.0391
# Epoch 64 Loss 0.0381
# Time taken for 1 epoch 111.18067669868469 sec
#
# Epoch 65 Batch 0 Loss 0.0261
# Epoch 65 Batch 100 Loss 0.0196
# Epoch 65 Batch 200 Loss 0.0408
# Epoch 65 Batch 300 Loss 0.0339
# Epoch 65 Batch 400 Loss 0.0333
# Epoch 65 Batch 500 Loss 0.0457
# Epoch 65 Batch 600 Loss 0.0288
# Epoch 65 Batch 700 Loss 0.0382
# Epoch 65 Batch 800 Loss 0.0486
# Epoch 65 Batch 900 Loss 0.0294
# Epoch 65 Batch 1000 Loss 0.0384
# Epoch 65 Batch 1100 Loss 0.0402
# Epoch 65 Batch 1200 Loss 0.0275
# Epoch 65 Loss 0.0383
# Time taken for 1 epoch 109.59838271141052 sec
#
# Epoch 66 Batch 0 Loss 0.0371
# Epoch 66 Batch 100 Loss 0.0366
# Epoch 66 Batch 200 Loss 0.0415
# Epoch 66 Batch 300 Loss 0.0321
# Epoch 66 Batch 400 Loss 0.0476
# Epoch 66 Batch 500 Loss 0.0329
# Epoch 66 Batch 600 Loss 0.0474
# Epoch 66 Batch 700 Loss 0.0520
# Epoch 66 Batch 800 Loss 0.0336
# Epoch 66 Batch 900 Loss 0.0443
# Epoch 66 Batch 1000 Loss 0.0723
# Epoch 66 Batch 1100 Loss 0.0465
# Epoch 66 Batch 1200 Loss 0.0619
# Epoch 66 Loss 0.0383
# Time taken for 1 epoch 111.01879382133484 sec
#
# Epoch 67 Batch 0 Loss 0.0352
# Epoch 67 Batch 100 Loss 0.0227
# Epoch 67 Batch 200 Loss 0.0157
# Epoch 67 Batch 300 Loss 0.0442
# Epoch 67 Batch 400 Loss 0.0264
# Epoch 67 Batch 500 Loss 0.0294
# Epoch 67 Batch 600 Loss 0.0068
# Epoch 67 Batch 700 Loss 0.0207
# Epoch 67 Batch 800 Loss 0.0334
# Epoch 67 Batch 900 Loss 0.0350
# Epoch 67 Batch 1000 Loss 0.0564
# Epoch 67 Batch 1100 Loss 0.0574
# Epoch 67 Batch 1200 Loss 0.0550
# Epoch 67 Loss 0.0381
# Time taken for 1 epoch 109.52528858184814 sec
#
# Epoch 68 Batch 0 Loss 0.0327
# Epoch 68 Batch 100 Loss 0.0255
# Epoch 68 Batch 200 Loss 0.0205
# Epoch 68 Batch 300 Loss 0.0261
# Epoch 68 Batch 400 Loss 0.0414
# Epoch 68 Batch 500 Loss 0.0318
# Epoch 68 Batch 600 Loss 0.0453
# Epoch 68 Batch 700 Loss 0.0336
# Epoch 68 Batch 800 Loss 0.0388
# Epoch 68 Batch 900 Loss 0.0441
# Epoch 68 Batch 1000 Loss 0.0812
# Epoch 68 Batch 1100 Loss 0.0496
# Epoch 68 Batch 1200 Loss 0.0572
# Epoch 68 Loss 0.0380
# Time taken for 1 epoch 110.86309790611267 sec
#
# Epoch 69 Batch 0 Loss 0.0261
# Epoch 69 Batch 100 Loss 0.0468
# Epoch 69 Batch 200 Loss 0.0124
# Epoch 69 Batch 300 Loss 0.0289
# Epoch 69 Batch 400 Loss 0.0493
# Epoch 69 Batch 500 Loss 0.0485
# Epoch 69 Batch 600 Loss 0.0377
# Epoch 69 Batch 700 Loss 0.0445
# Epoch 69 Batch 800 Loss 0.0237
# Epoch 69 Batch 900 Loss 0.0566
# Epoch 69 Batch 1000 Loss 0.0394
# Epoch 69 Batch 1100 Loss 0.0451
# Epoch 69 Batch 1200 Loss 0.0529
# Epoch 69 Loss 0.0378
# Time taken for 1 epoch 109.51503849029541 sec
#
# Epoch 70 Batch 0 Loss 0.0320
# Epoch 70 Batch 100 Loss 0.0263
# Epoch 70 Batch 200 Loss 0.0267
# Epoch 70 Batch 300 Loss 0.0157
# Epoch 70 Batch 400 Loss 0.0309
# Epoch 70 Batch 500 Loss 0.0738
# Epoch 70 Batch 600 Loss 0.0297
# Epoch 70 Batch 700 Loss 0.0303
# Epoch 70 Batch 800 Loss 0.0438
# Epoch 70 Batch 900 Loss 0.0344
# Epoch 70 Batch 1000 Loss 0.0494
# Epoch 70 Batch 1100 Loss 0.0637
# Epoch 70 Batch 1200 Loss 0.0310
# Epoch 70 Loss 0.0375
# Time taken for 1 epoch 111.12584638595581 sec
#
# Epoch 71 Batch 0 Loss 0.0237
# Epoch 71 Batch 100 Loss 0.0333
# Epoch 71 Batch 200 Loss 0.0478
# Epoch 71 Batch 300 Loss 0.0122
# Epoch 71 Batch 400 Loss 0.0380
# Epoch 71 Batch 500 Loss 0.0402
# Epoch 71 Batch 600 Loss 0.0450
# Epoch 71 Batch 700 Loss 0.0499
# Epoch 71 Batch 800 Loss 0.0350
# Epoch 71 Batch 900 Loss 0.0228
# Epoch 71 Batch 1000 Loss 0.0551
# Epoch 71 Batch 1100 Loss 0.0622
# Epoch 71 Batch 1200 Loss 0.0340
# Epoch 71 Loss 0.0373
# Time taken for 1 epoch 109.44994831085205 sec
#
# Epoch 72 Batch 0 Loss 0.0465
# Epoch 72 Batch 100 Loss 0.0384
# Epoch 72 Batch 200 Loss 0.0433
# Epoch 72 Batch 300 Loss 0.0450
# Epoch 72 Batch 400 Loss 0.0349
# Epoch 72 Batch 500 Loss 0.0125
# Epoch 72 Batch 600 Loss 0.0237
# Epoch 72 Batch 700 Loss 0.0363
# Epoch 72 Batch 800 Loss 0.0303
# Epoch 72 Batch 900 Loss 0.0354
# Epoch 72 Batch 1000 Loss 0.0676
# Epoch 72 Batch 1100 Loss 0.0672
# Epoch 72 Batch 1200 Loss 0.0470
# Epoch 72 Loss 0.0379
# Time taken for 1 epoch 110.92817997932434 sec
#
# Epoch 73 Batch 0 Loss 0.0245
# Epoch 73 Batch 100 Loss 0.0241
# Epoch 73 Batch 200 Loss 0.0242
# Epoch 73 Batch 300 Loss 0.0326
# Epoch 73 Batch 400 Loss 0.0469
# Epoch 73 Batch 500 Loss 0.0372
# Epoch 73 Batch 600 Loss 0.0336
# Epoch 73 Batch 700 Loss 0.0338
# Epoch 73 Batch 800 Loss 0.0252
# Epoch 73 Batch 900 Loss 0.0387
# Epoch 73 Batch 1000 Loss 0.0360
# Epoch 73 Batch 1100 Loss 0.0468
# Epoch 73 Batch 1200 Loss 0.0574
# Epoch 73 Loss 0.0376
# Time taken for 1 epoch 109.51405024528503 sec
#
# Epoch 74 Batch 0 Loss 0.0313
# Epoch 74 Batch 100 Loss 0.0409
# Epoch 74 Batch 200 Loss 0.0328
# Epoch 74 Batch 300 Loss 0.0282
# Epoch 74 Batch 400 Loss 0.0437
# Epoch 74 Batch 500 Loss 0.0268
# Epoch 74 Batch 600 Loss 0.0378
# Epoch 74 Batch 700 Loss 0.0265
# Epoch 74 Batch 800 Loss 0.0228
# Epoch 74 Batch 900 Loss 0.0628
# Epoch 74 Batch 1000 Loss 0.0484
# Epoch 74 Batch 1100 Loss 0.0307
# Epoch 74 Batch 1200 Loss 0.0751
# Epoch 74 Loss 0.0372
# Time taken for 1 epoch 110.9543149471283 sec
#
# Epoch 75 Batch 0 Loss 0.0222
# Epoch 75 Batch 100 Loss 0.0229
# Epoch 75 Batch 200 Loss 0.0239
# Epoch 75 Batch 300 Loss 0.0373
# Epoch 75 Batch 400 Loss 0.0595
# Epoch 75 Batch 500 Loss 0.0173
# Epoch 75 Batch 600 Loss 0.0312
# Epoch 75 Batch 700 Loss 0.0432
# Epoch 75 Batch 800 Loss 0.0401
# Epoch 75 Batch 900 Loss 0.0319
# Epoch 75 Batch 1000 Loss 0.0438
# Epoch 75 Batch 1100 Loss 0.0355
# Epoch 75 Batch 1200 Loss 0.0295
# Epoch 75 Loss 0.0366
# Time taken for 1 epoch 109.39666700363159 sec
#
# Epoch 76 Batch 0 Loss 0.0274
# Epoch 76 Batch 100 Loss 0.0379
# Epoch 76 Batch 200 Loss 0.0354
# Epoch 76 Batch 300 Loss 0.0320
# Epoch 76 Batch 400 Loss 0.0332
# Epoch 76 Batch 500 Loss 0.0668
# Epoch 76 Batch 600 Loss 0.0368
# Epoch 76 Batch 700 Loss 0.0485
# Epoch 76 Batch 800 Loss 0.0357
# Epoch 76 Batch 900 Loss 0.0359
# Epoch 76 Batch 1000 Loss 0.0381
# Epoch 76 Batch 1100 Loss 0.0563
# Epoch 76 Batch 1200 Loss 0.0489
# Epoch 76 Loss 0.0371
# Time taken for 1 epoch 110.97044324874878 sec
#
# Epoch 77 Batch 0 Loss 0.0229
# Epoch 77 Batch 100 Loss 0.0225
# Epoch 77 Batch 200 Loss 0.0505
# Epoch 77 Batch 300 Loss 0.0407
# Epoch 77 Batch 400 Loss 0.0233
# Epoch 77 Batch 500 Loss 0.0335
# Epoch 77 Batch 600 Loss 0.0310
# Epoch 77 Batch 700 Loss 0.0804
# Epoch 77 Batch 800 Loss 0.0489
# Epoch 77 Batch 900 Loss 0.0572
# Epoch 77 Batch 1000 Loss 0.0505
# Epoch 77 Batch 1100 Loss 0.0490
# Epoch 77 Batch 1200 Loss 0.0236
# Epoch 77 Loss 0.0368
# Time taken for 1 epoch 109.47656655311584 sec
#
# Epoch 78 Batch 0 Loss 0.0156
# Epoch 78 Batch 100 Loss 0.0343
# Epoch 78 Batch 200 Loss 0.0343
# Epoch 78 Batch 300 Loss 0.0506
# Epoch 78 Batch 400 Loss 0.0376
# Epoch 78 Batch 500 Loss 0.0282
# Epoch 78 Batch 600 Loss 0.0326
# Epoch 78 Batch 700 Loss 0.0293
# Epoch 78 Batch 800 Loss 0.0555
# Epoch 78 Batch 900 Loss 0.0393
# Epoch 78 Batch 1000 Loss 0.0331
# Epoch 78 Batch 1100 Loss 0.0483
# Epoch 78 Batch 1200 Loss 0.0611
# Epoch 78 Loss 0.0371
# Time taken for 1 epoch 111.17353558540344 sec
#
# Epoch 79 Batch 0 Loss 0.0195
# Epoch 79 Batch 100 Loss 0.0259
# Epoch 79 Batch 200 Loss 0.0299
# Epoch 79 Batch 300 Loss 0.0318
# Epoch 79 Batch 400 Loss 0.0177
# Epoch 79 Batch 500 Loss 0.0366
# Epoch 79 Batch 600 Loss 0.0159
# Epoch 79 Batch 700 Loss 0.0527
# Epoch 79 Batch 800 Loss 0.0279
# Epoch 79 Batch 900 Loss 0.0299
# Epoch 79 Batch 1000 Loss 0.0479
# Epoch 79 Batch 1100 Loss 0.0322
# Epoch 79 Batch 1200 Loss 0.0568
# Epoch 79 Loss 0.0366
# Time taken for 1 epoch 109.40961980819702 sec
#
# Epoch 80 Batch 0 Loss 0.0436
# Epoch 80 Batch 100 Loss 0.0237
# Epoch 80 Batch 200 Loss 0.0494
# Epoch 80 Batch 300 Loss 0.0302
# Epoch 80 Batch 400 Loss 0.0377
# Epoch 80 Batch 500 Loss 0.0326
# Epoch 80 Batch 600 Loss 0.0383
# Epoch 80 Batch 700 Loss 0.0378
# Epoch 80 Batch 800 Loss 0.0601
# Epoch 80 Batch 900 Loss 0.0364
# Epoch 80 Batch 1000 Loss 0.0681
# Epoch 80 Batch 1100 Loss 0.0570
# Epoch 80 Batch 1200 Loss 0.0467
# Epoch 80 Loss 0.0365
# Time taken for 1 epoch 110.87089443206787 sec
#
# Epoch 81 Batch 0 Loss 0.0208
# Epoch 81 Batch 100 Loss 0.0285
# Epoch 81 Batch 200 Loss 0.0385
# Epoch 81 Batch 300 Loss 0.0352
# Epoch 81 Batch 400 Loss 0.0242
# Epoch 81 Batch 500 Loss 0.0397
# Epoch 81 Batch 600 Loss 0.0379
# Epoch 81 Batch 700 Loss 0.0469
# Epoch 81 Batch 800 Loss 0.0379
# Epoch 81 Batch 900 Loss 0.0308
# Epoch 81 Batch 1000 Loss 0.0457
# Epoch 81 Batch 1100 Loss 0.0406
# Epoch 81 Batch 1200 Loss 0.0320
# Epoch 81 Loss 0.0365
# Time taken for 1 epoch 109.4148051738739 sec
#
# Epoch 82 Batch 0 Loss 0.0272
# Epoch 82 Batch 100 Loss 0.0365
# Epoch 82 Batch 200 Loss 0.0347
# Epoch 82 Batch 300 Loss 0.0336
# Epoch 82 Batch 400 Loss 0.0194
# Epoch 82 Batch 500 Loss 0.0453
# Epoch 82 Batch 600 Loss 0.0385
# Epoch 82 Batch 700 Loss 0.0427
# Epoch 82 Batch 800 Loss 0.0507
# Epoch 82 Batch 900 Loss 0.0413
# Epoch 82 Batch 1000 Loss 0.0521
# Epoch 82 Batch 1100 Loss 0.0361
# Epoch 82 Batch 1200 Loss 0.0434
# Epoch 82 Loss 0.0362
# Time taken for 1 epoch 110.98204159736633 sec
#
# Epoch 83 Batch 0 Loss 0.0189
# Epoch 83 Batch 100 Loss 0.0301
# Epoch 83 Batch 200 Loss 0.0292
# Epoch 83 Batch 300 Loss 0.0383
# Epoch 83 Batch 400 Loss 0.0134
# Epoch 83 Batch 500 Loss 0.0201
# Epoch 83 Batch 600 Loss 0.0382
# Epoch 83 Batch 700 Loss 0.0403
# Epoch 83 Batch 800 Loss 0.0361
# Epoch 83 Batch 900 Loss 0.0508
# Epoch 83 Batch 1000 Loss 0.0265
# Epoch 83 Batch 1100 Loss 0.0277
# Epoch 83 Batch 1200 Loss 0.0687
# Epoch 83 Loss 0.0361
# Time taken for 1 epoch 109.3865795135498 sec
#
# Epoch 84 Batch 0 Loss 0.0478
# Epoch 84 Batch 100 Loss 0.0313
# Epoch 84 Batch 200 Loss 0.0164
# Epoch 84 Batch 300 Loss 0.0394
# Epoch 84 Batch 400 Loss 0.0485
# Epoch 84 Batch 500 Loss 0.0331
# Epoch 84 Batch 600 Loss 0.0541
# Epoch 84 Batch 700 Loss 0.0299
# Epoch 84 Batch 800 Loss 0.0295
# Epoch 84 Batch 900 Loss 0.0354
# Epoch 84 Batch 1000 Loss 0.0207
# Epoch 84 Batch 1100 Loss 0.0675
# Epoch 84 Batch 1200 Loss 0.0566
# Epoch 84 Loss 0.0361
# Time taken for 1 epoch 110.78453159332275 sec
#
# Epoch 85 Batch 0 Loss 0.0267
# Epoch 85 Batch 100 Loss 0.0309
# Epoch 85 Batch 200 Loss 0.0198
# Epoch 85 Batch 300 Loss 0.0468
# Epoch 85 Batch 400 Loss 0.0497
# Epoch 85 Batch 500 Loss 0.0303
# Epoch 85 Batch 600 Loss 0.0352
# Epoch 85 Batch 700 Loss 0.0382
# Epoch 85 Batch 800 Loss 0.0428
# Epoch 85 Batch 900 Loss 0.0395
# Epoch 85 Batch 1000 Loss 0.0344
# Epoch 85 Batch 1100 Loss 0.0672
# Epoch 85 Batch 1200 Loss 0.0445
# Epoch 85 Loss 0.0363
# Time taken for 1 epoch 109.49215912818909 sec
#
# Epoch 86 Batch 0 Loss 0.0294
# Epoch 86 Batch 100 Loss 0.0206
# Epoch 86 Batch 200 Loss 0.0310
# Epoch 86 Batch 300 Loss 0.0183
# Epoch 86 Batch 400 Loss 0.0499
# Epoch 86 Batch 500 Loss 0.0328
# Epoch 86 Batch 600 Loss 0.0416
# Epoch 86 Batch 700 Loss 0.0316
# Epoch 86 Batch 800 Loss 0.0445
# Epoch 86 Batch 900 Loss 0.0242
# Epoch 86 Batch 1000 Loss 0.0351
# Epoch 86 Batch 1100 Loss 0.0289
# Epoch 86 Batch 1200 Loss 0.0656
# Epoch 86 Loss 0.0363
# Time taken for 1 epoch 111.04997324943542 sec
#
# Epoch 87 Batch 0 Loss 0.0543
# Epoch 87 Batch 100 Loss 0.0287
# Epoch 87 Batch 200 Loss 0.0310
# Epoch 87 Batch 300 Loss 0.0307
# Epoch 87 Batch 400 Loss 0.0319
# Epoch 87 Batch 500 Loss 0.0313
# Epoch 87 Batch 600 Loss 0.0387
# Epoch 87 Batch 700 Loss 0.0327
# Epoch 87 Batch 800 Loss 0.0225
# Epoch 87 Batch 900 Loss 0.0247
# Epoch 87 Batch 1000 Loss 0.0260
# Epoch 87 Batch 1100 Loss 0.0328
# Epoch 87 Batch 1200 Loss 0.0553
# Epoch 87 Loss 0.0360
# Time taken for 1 epoch 109.38567113876343 sec
#
# Epoch 88 Batch 0 Loss 0.0340
# Epoch 88 Batch 100 Loss 0.0282
# Epoch 88 Batch 200 Loss 0.0327
# Epoch 88 Batch 300 Loss 0.0170
# Epoch 88 Batch 400 Loss 0.0314
# Epoch 88 Batch 500 Loss 0.0437
# Epoch 88 Batch 600 Loss 0.0329
# Epoch 88 Batch 700 Loss 0.0177
# Epoch 88 Batch 800 Loss 0.0487
# Epoch 88 Batch 900 Loss 0.0478
# Epoch 88 Batch 1000 Loss 0.0163
# Epoch 88 Batch 1100 Loss 0.0438
# Epoch 88 Batch 1200 Loss 0.0350
# Epoch 88 Loss 0.0366
# Time taken for 1 epoch 110.98657965660095 sec
#
# Epoch 89 Batch 0 Loss 0.0285
# Epoch 89 Batch 100 Loss 0.0340
# Epoch 89 Batch 200 Loss 0.0313
# Epoch 89 Batch 300 Loss 0.0220
# Epoch 89 Batch 400 Loss 0.0311
# Epoch 89 Batch 500 Loss 0.0638
# Epoch 89 Batch 600 Loss 0.0405
# Epoch 89 Batch 700 Loss 0.0327
# Epoch 89 Batch 800 Loss 0.0312
# Epoch 89 Batch 900 Loss 0.0408
# Epoch 89 Batch 1000 Loss 0.0347
# Epoch 89 Batch 1100 Loss 0.0475
# Epoch 89 Batch 1200 Loss 0.0570
# Epoch 89 Loss 0.0360
# Time taken for 1 epoch 109.4899115562439 sec
#
# Epoch 90 Batch 0 Loss 0.0191
# Epoch 90 Batch 100 Loss 0.0233
# Epoch 90 Batch 200 Loss 0.0297
# Epoch 90 Batch 300 Loss 0.0303
# Epoch 90 Batch 400 Loss 0.0262
# Epoch 90 Batch 500 Loss 0.0262
# Epoch 90 Batch 600 Loss 0.0459
# Epoch 90 Batch 700 Loss 0.0596
# Epoch 90 Batch 800 Loss 0.0334
# Epoch 90 Batch 900 Loss 0.0291
# Epoch 90 Batch 1000 Loss 0.0415
# Epoch 90 Batch 1100 Loss 0.0479
# Epoch 90 Batch 1200 Loss 0.0534
# Epoch 90 Loss 0.0360
# Time taken for 1 epoch 110.92037558555603 sec
#
# Epoch 91 Batch 0 Loss 0.0319
# Epoch 91 Batch 100 Loss 0.0342
# Epoch 91 Batch 200 Loss 0.0678
# Epoch 91 Batch 300 Loss 0.0233
# Epoch 91 Batch 400 Loss 0.0309
# Epoch 91 Batch 500 Loss 0.0439
# Epoch 91 Batch 600 Loss 0.0346
# Epoch 91 Batch 700 Loss 0.0367
# Epoch 91 Batch 800 Loss 0.0471
# Epoch 91 Batch 900 Loss 0.0520
# Epoch 91 Batch 1000 Loss 0.0400
# Epoch 91 Batch 1100 Loss 0.0408
# Epoch 91 Batch 1200 Loss 0.0343
# Epoch 91 Loss 0.0352
# Time taken for 1 epoch 109.28486728668213 sec
#
# Epoch 92 Batch 0 Loss 0.0600
# Epoch 92 Batch 100 Loss 0.0344
# Epoch 92 Batch 200 Loss 0.0463
# Epoch 92 Batch 300 Loss 0.0382
# Epoch 92 Batch 400 Loss 0.0335
# Epoch 92 Batch 500 Loss 0.0318
# Epoch 92 Batch 600 Loss 0.0375
# Epoch 92 Batch 700 Loss 0.0191
# Epoch 92 Batch 800 Loss 0.0511
# Epoch 92 Batch 900 Loss 0.0225
# Epoch 92 Batch 1000 Loss 0.0373
# Epoch 92 Batch 1100 Loss 0.0451
# Epoch 92 Batch 1200 Loss 0.0339
# Epoch 92 Loss 0.0354
# Time taken for 1 epoch 110.8618471622467 sec
#
# Epoch 93 Batch 0 Loss 0.0367
# Epoch 93 Batch 100 Loss 0.0170
# Epoch 93 Batch 200 Loss 0.0295
# Epoch 93 Batch 300 Loss 0.0570
# Epoch 93 Batch 400 Loss 0.0301
# Epoch 93 Batch 500 Loss 0.0358
# Epoch 93 Batch 600 Loss 0.0618
# Epoch 93 Batch 700 Loss 0.0420
# Epoch 93 Batch 800 Loss 0.0293
# Epoch 93 Batch 900 Loss 0.0456
# Epoch 93 Batch 1000 Loss 0.0222
# Epoch 93 Batch 1100 Loss 0.0612
# Epoch 93 Batch 1200 Loss 0.0477
# Epoch 93 Loss 0.0356
# Time taken for 1 epoch 109.31898999214172 sec
#
# Epoch 94 Batch 0 Loss 0.0324
# Epoch 94 Batch 100 Loss 0.0201
# Epoch 94 Batch 200 Loss 0.0335
# Epoch 94 Batch 300 Loss 0.0360
# Epoch 94 Batch 400 Loss 0.0406
# Epoch 94 Batch 500 Loss 0.0296
# Epoch 94 Batch 600 Loss 0.0328
# Epoch 94 Batch 700 Loss 0.0501
# Epoch 94 Batch 800 Loss 0.0399
# Epoch 94 Batch 900 Loss 0.0579
# Epoch 94 Batch 1000 Loss 0.0329
# Epoch 94 Batch 1100 Loss 0.0333
# Epoch 94 Batch 1200 Loss 0.0227
# Epoch 94 Loss 0.0356
# Time taken for 1 epoch 110.93194818496704 sec
#
# Epoch 95 Batch 0 Loss 0.0519
# Epoch 95 Batch 100 Loss 0.0163
# Epoch 95 Batch 200 Loss 0.0067
# Epoch 95 Batch 300 Loss 0.0377
# Epoch 95 Batch 400 Loss 0.0598
# Epoch 95 Batch 500 Loss 0.0253
# Epoch 95 Batch 600 Loss 0.0213
# Epoch 95 Batch 700 Loss 0.0392
# Epoch 95 Batch 800 Loss 0.0259
# Epoch 95 Batch 900 Loss 0.0381
# Epoch 95 Batch 1000 Loss 0.0263
# Epoch 95 Batch 1100 Loss 0.0780
# Epoch 95 Batch 1200 Loss 0.0600
# Epoch 95 Loss 0.0351
# Time taken for 1 epoch 109.46535730361938 sec
#
# Epoch 96 Batch 0 Loss 0.0423
# Epoch 96 Batch 100 Loss 0.0428
# Epoch 96 Batch 200 Loss 0.0161
# Epoch 96 Batch 300 Loss 0.0235
# Epoch 96 Batch 400 Loss 0.0295
# Epoch 96 Batch 500 Loss 0.0473
# Epoch 96 Batch 600 Loss 0.0337
# Epoch 96 Batch 700 Loss 0.0515
# Epoch 96 Batch 800 Loss 0.0417
# Epoch 96 Batch 900 Loss 0.0304
# Epoch 96 Batch 1000 Loss 0.0423
# Epoch 96 Batch 1100 Loss 0.0377
# Epoch 96 Batch 1200 Loss 0.0259
# Epoch 96 Loss 0.0352
# Time taken for 1 epoch 110.71663045883179 sec
#
# Epoch 97 Batch 0 Loss 0.0186
# Epoch 97 Batch 100 Loss 0.0297
# Epoch 97 Batch 200 Loss 0.0354
# Epoch 97 Batch 300 Loss 0.0370
# Epoch 97 Batch 400 Loss 0.0314
# Epoch 97 Batch 500 Loss 0.0354
# Epoch 97 Batch 600 Loss 0.0653
# Epoch 97 Batch 700 Loss 0.0372
# Epoch 97 Batch 800 Loss 0.0339
# Epoch 97 Batch 900 Loss 0.0397
# Epoch 97 Batch 1000 Loss 0.0602
# Epoch 97 Batch 1100 Loss 0.0350
# Epoch 97 Batch 1200 Loss 0.0394
# Epoch 97 Loss 0.0355
# Time taken for 1 epoch 109.34174966812134 sec
#
# Epoch 98 Batch 0 Loss 0.0282
# Epoch 98 Batch 100 Loss 0.0306
# Epoch 98 Batch 200 Loss 0.0204
# Epoch 98 Batch 300 Loss 0.0321
# Epoch 98 Batch 400 Loss 0.0255
# Epoch 98 Batch 500 Loss 0.0548
# Epoch 98 Batch 600 Loss 0.0407
# Epoch 98 Batch 700 Loss 0.0401
# Epoch 98 Batch 800 Loss 0.0468
# Epoch 98 Batch 900 Loss 0.0340
# Epoch 98 Batch 1000 Loss 0.0256
# Epoch 98 Batch 1100 Loss 0.0447
# Epoch 98 Batch 1200 Loss 0.0195
# Epoch 98 Loss 0.0350
# Time taken for 1 epoch 110.77042818069458 sec
#
# Epoch 99 Batch 0 Loss 0.0363
# Epoch 99 Batch 100 Loss 0.0169
# Epoch 99 Batch 200 Loss 0.0260
# Epoch 99 Batch 300 Loss 0.0326
# Epoch 99 Batch 400 Loss 0.0329
# Epoch 99 Batch 500 Loss 0.0297
# Epoch 99 Batch 600 Loss 0.0420
# Epoch 99 Batch 700 Loss 0.0533
# Epoch 99 Batch 800 Loss 0.0300
# Epoch 99 Batch 900 Loss 0.0414
# Epoch 99 Batch 1000 Loss 0.0247
# Epoch 99 Batch 1100 Loss 0.0627
# Epoch 99 Batch 1200 Loss 0.0295
# Epoch 99 Loss 0.0353
# Time taken for 1 epoch 109.17710256576538 sec
#
# Epoch 100 Batch 0 Loss 0.0107
# Epoch 100 Batch 100 Loss 0.0403
# Epoch 100 Batch 200 Loss 0.0219
# Epoch 100 Batch 300 Loss 0.0500
# Epoch 100 Batch 400 Loss 0.0235
# Epoch 100 Batch 500 Loss 0.0278
# Epoch 100 Batch 600 Loss 0.0483
# Epoch 100 Batch 700 Loss 0.0288
# Epoch 100 Batch 800 Loss 0.0172
# Epoch 100 Batch 900 Loss 0.0258
# Epoch 100 Batch 1000 Loss 0.0428
# Epoch 100 Batch 1100 Loss 0.0367
# Epoch 100 Batch 1200 Loss 0.0270
# Epoch 100 Loss 0.0351
# Time taken for 1 epoch 110.80085730552673 sec

# %% [markdown]
# ## Translate
#
# * The evaluate function is similar to the training loop, except we don't use *teacher forcing* here. The input to the decoder at each time step is its previous predictions along with the hidden state and the encoder output.
# * Stop predicting when the model predicts the *end token*.
# * And store the *attention weights for every time step*.
#
# Note: The encoder output is calculated only once for one input.

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_out, enc_hidden = encoder(inputs, hidden[0])

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden, attention_weights = decoder(dec_input,
                                                         dec_hidden,
                                                         enc_out)

    # storing the attention weights to plot later on
    attention_weights = tf.reshape(attention_weights, (-1, ))
    attention_plot[t] = attention_weights.numpy()

    predicted_id = tf.argmax(predictions[0]).numpy()

    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence, attention_plot

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence, attention_plot

# %%
# function for plotting the attention weights
def plot_attention(attention, sentence, predicted_sentence):
  fig = plt.figure(figsize=(10,10))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  fontdict = {'fontsize': 14}

  ax.set_xticklabels([''] + sentence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sentence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
def translate(sentence):
  result, sentence, attention_plot = evaluate(sentence)
  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

  attention_plot = attention_plot[:len(result.split(' ')), :len(sentence.split(' '))]
  plot_attention(attention_plot, sentence.split(' '), result.split(' '))

# %% [markdown]
# ## Restore the latest checkpoint and test

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('Здесь хорошо.')
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: it's in here . <end>

# %%
translate('Я не смогу поехать.')
# Out:
# Input: <start> я не смогу поехать . <end>
# Predicted translation: i can't go . <end>

# %%
translate(u'Вы еще дома?')
# Out:
# Input: <start> вы еще дома ? <end>
# Predicted translation: are you still at home ? <end>

# %%
translate(u'Вы все еще дома?')
# Out:
# Input: <start> вы все еще дома ? <end>
# Predicted translation: are you still at home ? <end>

# %%
translate(u'Попробуй сделать это.')
# Out:
# Input: <start> попробуй сделать это . <end>
# Predicted translation: try to do this . <end>

# %%
translate(u'Я люблю, когда идет снег.') # i love why i can snow - ошибка перевода
# Out:
# Input: <start> я люблю , когда идет снег . <end>
# Predicted translation: i love why i can snow . <end>

# %%
translate(u'Я никогда такого не делаю.')
# Out:
# Input: <start> я никогда такого не делаю . <end>
# Predicted translation: i do not do that . <end>

# %%
translate(u'Какие ваши доказательства.')
# Out:
# Input: <start> какие ваши доказательства . <end>
# Predicted translation: what is your evidence . <end>

# %%
translate(u'Руки вверх')
# Out:
# Input: <start> руки вверх <end>
# Predicted translation: your hands are up . <end>

# %% [markdown]
# Особой разницы в переводе не видно
